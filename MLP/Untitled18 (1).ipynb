# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import metrics
import statsmodels.api as sm
from sklearn.metrics import accuracy_score
import lightgbm
from lightgbm import LGBMClassifier
from sklearn import svm
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

from google.colab import drive
drive.mount('/content/drive')

file = 'drive/MyDrive/data/Retrosheet_2010_2019/2010_to_2019_seasons.csv'
game_df = pd.read_csv(file)

game_col_del = '''VisitorGDP,VisitorCI,HomeGDP,HomeCI, DoubleHeader, DayOfWeek, VisitingTeamLeague, HomeTeamLeague, DayNight, CompletionInfo,ForfeitInfo, ProtestInfo,Duration, VisitorLineScore, HomeLineScore, UmpireHID, UmpireHName, Umpire1BID, Umpire1BName, Umpire2BID,Umpire2BName, Umpire3BID, Umpire3BName, UmpireLFID, UmpireLFName, UmpireRFID,UmpireRFName, VisitorManagerID, VisitorManagerName, HomeManagerID, HomeManagerName,WinningPitcherID, WinningPitcherName, LosingPitcherID, LosingPitcherNAme,SavingPitcherID, SavingPitcherName, GameWinningRBIID, GameWinningRBIName, VisitorBatting1Position, VisitorBatting2Position, VisitorBatting3Position,VisitorBatting4Position, VisitorBatting5Position, VisitorBatting6Position,VisitorBatting7Position, VisitorBatting8Position, VisitorBatting9Position,HomeBatting1Position, HomeBatting2Position, HomeBatting3Position,HomeBatting4Position, HomeBatting5Position, HomeBatting6Position,HomeBatting7Position, HomeBatting8Position, HomeBatting9Position,AdditionalInfo, AcquisitionInfo'''
game_col_del = game_col_del.replace(" ", "")
game_col_del = game_col_del.split(",")

game_df.drop(game_col_del,axis=1,inplace=True)

my_attendence={'BOS':37755, 'LAA':45517, 'CWS':40615, 'KC':37903, 'OAK':56782, 'TEX':40300, 'ARI':48686, 'ATL':41084, 'CIN':42319,
       'HOU':41168, 'MIL':41900, 'NYM':41922, 'PIT':38747, 'WAS':41339, 'TB':42735, 'BAL':44970, 'DET':41083, 'COL':50144,
       'MIA':37442, 'SF':41265, 'CLE':34830, 'MIN':38544, 'SEA':47929, 'TOR':49282, 'CHC':41649, 'PHI':42792, 'SD':40209, 'STL':45494,
       'NYY':54251, 'LAD':56000}
# Had an extra team due to the Marlins having two different labels. Updating their team name to MIA
game_df.replace(to_replace='FLO', value='MIA', inplace=True)

# Updating game_df so team abbreviations match. Will be leveraged when aggregating teams stats
game_df.replace(to_replace={"NYA":"NYY", "SDN":"SD", "CHN":"CHC", "SLN":"STL", "SFN":"SF", "LAN":"LAD", "TBA":"TB", "KCA":"KC", "CHA":"CWS", "ANA":"LAA", "NYN":"NYM"}, inplace=True)

for key, value in my_attendence.items():
  game_df.loc[game_df['HomeTeam']==key,'Attendence']=game_df.loc[game_df['HomeTeam']==key,'Attendence']/value


file4 = 'drive/MyDrive/data/park_factors.csv'
parkfactor_df = pd.read_csv(file4, encoding='cp949')
parkfactor_df

# Had an extra team due to the Marlins having two different labels. Updating their team name to MIA
parkfactor_df.replace(to_replace='FLO', value='MIA', inplace=True)

# Updating game_df so team abbreviations match. Will be leveraged when aggregating teams stats
parkfactor_df.replace(to_replace={"NYA":"NYY", "SDN":"SD", "CHN":"CHC", "SLN":"STL", "SFN":"SF", "LAN":"LAD", "TBA":"TB", "KCA":"KC", "CHA":"CWS", "ANA":"LAA", "NYN":"NYM"}, inplace=True)


game_df = pd.merge(game_df, parkfactor_df, on="HomeTeam")

col_del = ['VisitorBatting1PlayerID', 'VisitorBatting1Name', 'VisitorBatting2PlayerID', 'VisitorBatting2Name', 'VisitorBatting3PlayerID', 'VisitorBatting3Name', 'VisitorBatting4PlayerID', 'VisitorBatting4Name', 'VisitorBatting5PlayerID', 'VisitorBatting5Name', 'VisitorBatting6PlayerID', 'VisitorBatting6Name', 'VisitorBatting7PlayerID', 'VisitorBatting7Name', 'VisitorBatting8PlayerID', 'VisitorBatting8Name', 'VisitorBatting9PlayerID', 'VisitorBatting9Name', 'HomeBatting1PlayerID', 'HomeBatting1Name', 'HomeBatting2PlayerID', 'HomeBatting2Name', 'HomeBatting3PlayerID', 'HomeBatting3Name', 'HomeBatting4PlayerID', 'HomeBatting4Name', 'HomeBatting5PlayerID', 'HomeBatting5Name', 'HomeBatting6PlayerID', 'HomeBatting6Name', 'HomeBatting7PlayerID', 'HomeBatting7Name', 'HomeBatting8PlayerID', 'HomeBatting8Name', 'HomeBatting9PlayerID', 'HomeBatting9Name']
game_df.drop(col_del,axis=1,inplace=True)
game_df = game_df.rename(columns={"VisitingTeam":"VisitorTeam","VisitingTeamGameNumber":"VisitorTeamGameNumber"})

game_df['Date'] = pd.to_datetime(game_df['Date'].astype(str), format='%Y%m%d')
game_df['current_year'] = game_df['Date'].dt.year

game_df['prior_year']=game_df['current_year']-1
print(game_df.Attendence)
trend=1 #몇일 롤링
game_df[f'{trend}d_home_attendance'] = game_df.groupby(['current_year', 'HomeTeam'])['Attendence'].transform(lambda x: round(x.rolling(trend).mean().shift(periods=1, axis=0), 3))
print(game_df[f'{trend}d_home_attendance'])

away_inning = game_df['LengthInOuts']//2
home_inning = game_df['LengthInOuts']- away_inning


game_df['VisitorOffInn'] = away_inning
game_df['VisitorDifInn'] = home_inning
game_df['HomeOffInn'] = home_inning
game_df['HomeDifInn'] = away_inning

game_df['Home_team_won?'] = game_df['HomeRunsScore'] > game_df['VisitorRunsScored']
game_df['Visitor_team_won?'] = game_df['HomeRunsScore'] < game_df['VisitorRunsScored']

bat_stat = [ 'TeamGameNumber','Team','AB','H','D','T','HR','RBI','SH','SF',
'HBP','BB','IBB','K','SB','CS','LOB','Pitchers',
'ER','TER','WP','Balks','PO','A','E','Passed','DB','TP','OffInn','DifInn','_team_won?']
pit_stat = ['H', 'D', 'T', 'HR', 'RBI', 'SH', 'SF', 'HBP', 'BB', 'IBB', 'K', 'LOB', 'ER','DB','AB']

select_stat = ['Date']
select_stat += ['Home'+i for i in bat_stat]+['Visitor'+i for i in pit_stat]
rename1 = {'Visitor'+i:'Pit'+i for i in pit_stat}
rename2 = {'Home'+i:i for i in bat_stat}

## Home 시각 
select_stat = ['Date']
select_stat += ['Home'+i for i in bat_stat]+['Visitor'+i for i in pit_stat]
rename1 = {'Visitor'+i:'Pit'+i for i in pit_stat}
rename2 = {'Home'+i:i for i in bat_stat}
Home = game_df.copy()
Home = Home[select_stat].rename(columns=rename1)
Home = Home.rename(columns=rename2)
# away 시각
select_stat = ['Date']
select_stat += ['Visitor'+i for i in bat_stat]+['Home'+i for i in pit_stat]
rename1 = {'Home'+i:'Pit'+i for i in pit_stat}
rename2 = {'Visitor'+i:i for i in bat_stat}
Visitor = game_df.copy()
Visitor = Visitor[select_stat].rename(columns=rename1)
Visitor = Visitor.rename(columns=rename2)

sep_team = pd.concat([Home,Visitor])
sep_team = sep_team.rename(columns={'PitDB':'DP'})
sep_team

col = ['AB', 'H', 'D', 'T', 'HR', 'RBI','DP',
       'SF', 'BB', 'K', 'SB', 'CS', 'LOB', 'Pitchers', 'ER', 'TER', 'WP','PitAB',
       'Balks', 'PO', 'A', 'E', 'Passed', 'DB', 'TP', 'OffInn', 'DifInn',
       'PitH', 'PitD', 'PitT', 'PitHR', 'PitRBI', 'PitSF',
       'PitBB', 'PitK', 'PitLOB', 'PitER']


a = sep_team.copy()
sep_team['year']= sep_team.Date.dt.year
sep_team[col] = sep_team.groupby(['year','Team'])[col].transform(lambda x: x.expanding(1).sum())
sep_team[col] = sep_team[col].subtract(a[col])
sep_team = sep_team[sep_team['TeamGameNumber']>=10] #최소 10경기 이상
sep_team

select_feature = ['Date', 'TeamGameNumber', 'Team','_team_won?']
# feature selection
select_feature += ['AB', 'H', 'D', 'T', 'HR', 'RBI','BB', 'K','DP', 'HBP','IBB','SF','SH',#bat stat
                    'ER','OffInn','DifInn' # game info
                    ,'PitAB','PitH', 'PitD', 'PitT', 'PitHR', 'PitRBI', 'PitSF', 'PitBB',"PitIBB","PitHBP" ,'PitK','PitLOB', 'PitER'
                    ]
sep = sep_team[select_feature] 
# H, OBP, SLG, ISO, Babip, RC, wOBA X, K, BB, RBI, K/B, HR   
# 타자 가공
sep['RC'] = ((sep['H']+sep['BB']+sep['HBP']-sep['DP'])
        *(sep['H']+2*sep['D']+3*sep['T']+4*sep['HR']+0.52*(sep['SF']+sep['SH'])+0.26*(sep['BB']+sep['HBP']-sep['IBB']))
        )/(sep['AB']*sep['AB']) #득점 생산


#사구,사사구, 고의사구 통합
sep['BB'] += sep['HBP']+sep['IBB']
sep['PitBB'] += sep['PitHBP']+sep['PitIBB']
#del sep['HBP'],sep['IBB'],sep['PitHBP'],sep['PitIBB']
# 희생번트, 희생플라이 통합
sep['PitSF'] += sep_team['PitSH']
sep['SF'] += sep['SH']
#del sep['SH'],sep['PitSH']

sep['K/B'] = sep['K']/(sep['BB']+0.5)
sep['PA'] = sep['AB'] - sep['BB'] - sep['SF'] # 타수
sep['Babip'] = (sep['H']+sep['D']+sep['T']) / (sep['PA']-sep['K']-sep['HR']-sep['SF']) # 인플레이 타구
sep['SLG'] = (sep['H']+2*sep['D']+3*sep['T']+4*sep['HR'])/sep['PA'] # 장타율
sep['H'] = sep['H']/sep['PA'] # 안타율
sep['D'] = sep['D']/sep['PA'] # 안타율
sep['T'] = sep['T']/sep['PA'] # 안타율
sep['HR'] = sep['HR']/sep['PA'] # 안타율
sep['BB'] = sep['BB']/sep['PA'] # 볼넷
sep['RBI'] = sep['RBI']/sep['TeamGameNumber'] # 득점

sep['OBP'] = (sep['H']+sep['BB']) #출루율
sep['OPS'] = sep['SLG']+sep['OBP'] #OPS
sep['GPA'] = (1.8*sep['OBP']+sep['SLG'])/4#GPA(Gross Production Average) - park factor를 적용해야함
sep['ISO'] = sep['SLG'] - sep['H']
# 투수 가공
# PitH, PitOBP, PitSLG, PitOPS, PitHR, EAR, PitB, PitK, PitK/B, WHIP, kwERA
sep['ERA'] = sep['PitER']/sep['DifInn']
sep['TotalH'] = sep['PitH']+sep['PitD']+sep['PitT']+sep['PitHR']
sep['TotalBB'] = sep['PitBB']+sep['PitHBP']
sep['PitPA'] = sep['PitAB'] - sep['TotalBB'] - sep['PitSF']
sep['kwERA'] = (5.40-12*(sep['PitK'] - sep['TotalBB']))/sep['PitPA']
sep['WHIP'] = (sep['TotalH']+sep['TotalBB'])/sep['DifInn']
sep['PitK'] = sep['PitK']/sep['DifInn']
sep['PitB'] = sep['TotalBB']/sep['DifInn']
sep['PitK/B'] = sep['PitK']/(sep['PitB']+0.5)


sep['PitSLG'] = (sep['PitH']+2*sep['PitD']+3*sep['PitT']+4*sep['PitHR'])/sep['PitPA'] # 피장타율
sep['PitH'] = sep['PitH']/sep['PitPA'] # 피안타율
sep['PitOBP'] = (sep['TotalH']+sep['TotalBB']) / sep['PitAB'] #피출루율
sep['PitOPS'] = sep['PitSLG']+sep['PitOBP'] #피OPS
sep['PitHR'] /= sep['PitPA']

#ParkFactors

temp = sep
game_log = game_df[['Date','VisitorTeam','HomeTeam','VisitorTeamGameNumber','HomeTeamGameNumber',f'{trend}d_home_attendance','ParkFactors']]

game_log = game_log[game_log.VisitorTeamGameNumber>=10]
game_log = game_log[game_log.HomeTeamGameNumber>=10]



game_log = pd.merge(game_log,temp,left_on = ['Date','VisitorTeam'], right_on = ['Date','Team'],how='left')
game_log = pd.merge(game_log,temp,left_on = ['Date','HomeTeam'], right_on = ['Date','Team'],how='left')

game_log['year'] = game_log.Date.dt.year



y_cols = ['_team_won?_x']
select = ['H','OBP','SLG','ISO','Babip','RC','K','BB','RBI','K/B','HR','PitH','PitOBP','PitSLG','PitOPS','PitHR','ERA','PitB','PitK','PitK/B','WHIP']
#select = ['H', 'D', 'T', 'HR', 'RBI', 'BB']
#x_cols = [i+'_x' for i in select]
#x_cols += [i+'_y' for i in select]

for i in select:
  print(i)
  
  game_log[i]=game_log[i+'_x']/game_log[i+'_y']
print(game_log.info())
x_cols=select
x_cols += [f'{trend}d_home_attendance']
x_cols += ['ParkFactors']
game_log=game_log.replace([np.inf, -np.inf], np.nan)
game_log.dropna()
train = game_log[game_log.year!=2019]
test = game_log[game_log.year==2019]
train = train.dropna()
test = test.dropna()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 0        0.991657
# 1        1.006489
# 2        1.012793
# 3        0.982228
# 4        0.980585
#            ...
# 24292    0.868982
# 24293    0.861661
# 24294    0.959000
# 24295    0.905446
# 24296    0.856214
# Name: Attendence, Length: 24297, dtype: float64
# 0          NaN
# 1        0.992
# 2        1.006
# 3        1.013
# 4        0.982
#          ...
# 24292    0.934
# 24293    0.869
# 24294    0.862
# 24295    0.959
# 24296    0.905
# Name: 1d_home_attendance, Length: 24297, dtype: float64
# H
# OBP
# SLG
# ISO
# Babip
# RC
# K
# BB
# RBI
# K/B
# HR
# PitH
# PitOBP
# PitSLG
# PitOPS
# PitHR
# ERA
# PitB
# PitK
# PitK/B
# WHIP
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24464 entries, 0 to 24463
# Columns: 133 entries, Date to WHIP
# dtypes: bool(2), datetime64[ns](1), float64(111), int64(15), object(4)
# memory usage: 24.7+ MB
# None

# %%
game_log.describe()
# Out:
#        VisitorTeamGameNumber  HomeTeamGameNumber  1d_home_attendance  \
# count           24464.000000        24464.000000        24461.000000
# mean               86.454872           86.449804            0.682864
# std                44.299550           44.306926            0.239825
# min                10.000000           10.000000            0.000000
# 25%                48.000000           48.000000            0.508000
# 50%                87.000000           87.000000            0.702000
# 75%               125.000000          125.000000            0.881000
# max               163.000000          163.000000            1.580000
#
#         ParkFactors  TeamGameNumber_x          AB_x           H_x  \
# count  24464.000000      24464.000000  24464.000000  24464.000000
# mean       1.004674         86.454872   4100.900139      0.284216
# std        0.120131         44.299552    818.757280      0.015510
# min        0.798000         10.000000   1654.000000      0.238076
# 25%        0.917000         48.000000   3392.000000      0.273670
# 50%        1.003000         87.000000   4106.000000      0.282857
# 75%        1.074000        125.000000   4803.000000      0.293738
# max        1.394000        163.000000   5738.000000      0.351197
#
#                 D_x           T_x          HR_x  ...          PitH  \
# count  24464.000000  24464.000000  24464.000000  ...  24462.000000
# mean       0.056292      0.005962      0.035297  ...      1.022928
# std        0.006265      0.002210      0.008998  ...      0.110683
# min        0.039328      0.000880      0.012302  ...      0.514812
# 25%        0.051827      0.004374      0.028557  ...      0.948135
# 50%        0.055899      0.005810      0.034474  ...      1.017804
# 75%        0.059892      0.007221      0.041835  ...      1.090584
# max        0.084293      0.016243      0.063880  ...      2.103067
#
#              PitOBP        PitSLG        PitOPS         PitHR           ERA  \
# count  24463.000000  24462.000000  24463.000000  24430.000000  24461.000000
# mean       1.018819      1.032877      1.025832      1.110184      1.037327
# std        0.109176      0.153358      0.130782      0.434539      0.276134
# min        0.000000      0.471481      0.000000      0.266755      0.341784
# 25%        0.945538      0.931638      0.938319      0.855622      0.862520
# 50%        1.013402      1.021353      1.017974      1.037421      1.000967
# 75%        1.086214      1.121269      1.104005      1.273894      1.167666
# max        2.036987      2.605168      2.263405     11.542735     10.735495
#
#                PitB          PitK        PitK/B          WHIP
# count  24463.000000  24462.000000  24462.000000  24463.000000
# mean       1.002816      0.987673      0.993916      1.003989
# std        0.207037      0.148753      0.161195      0.126097
# min        0.000000      0.557858      0.530280      0.000000
# 25%        0.861638      0.882094      0.879471      0.918909
# 50%        0.982300      0.974114      0.980006      0.996117
# 75%        1.119727      1.077228      1.090661      1.079073
# max        3.228910      1.941696      2.340909      2.142820
#
# [8 rows x 126 columns]

# %%
'''
    Z-score normalization
'''
scaler = StandardScaler()
scaler.fit(train[x_cols])
X_train = scaler.transform(train[x_cols])
X_test = scaler.transform(test[x_cols])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-43158ab9e17c> in <module>()
#       3 '''
#       4 scaler = StandardScaler()
# ----> 5 scaler.fit(train[x_cols])
#       6 X_train = scaler.transform(train[x_cols])
#       7 X_test = scaler.transform(test[x_cols])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     845             dtype=FLOAT_DTYPES,
#     846             force_all_finite="allow-nan",
# --> 847             reset=first_call,
#     848         )
#     849         n_features = X.shape[1]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %%
X_train = train[x_cols]
y_train = train[y_cols]*1

X_test = test[x_cols]
y_test = test[y_cols]*1

model = sm.Logit(y_train,X_train)
results = model.fit()
print(results.summary())

y_hat = results.predict( X_train)
y_hat = list(map(round,y_hat))
print('Train accuracy = ', accuracy_score(y_train, y_hat))

y_hat = results.predict( X_test)
y_hat = list(map(round,y_hat))
print('Test accuracy = ', accuracy_score(y_test, y_hat))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.681472
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           _team_won?_x   No. Observations:                21929
# Model:                          Logit   Df Residuals:                    21906
# Method:                           MLE   Df Model:                           22
# Date:                Thu, 05 May 2022   Pseudo R-squ.:                 0.01302
# Time:                        20:17:40   Log-Likelihood:                -14944.
# converged:                       True   LL-Null:                       -15141.
# Covariance Type:            nonrobust   LLR p-value:                 6.486e-70
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# H                     -0.3499      0.927     -0.377      0.706      -2.167       1.467
# OBP                    1.6591      1.084      1.530      0.126      -0.466       3.785
# SLG                    2.2295      1.082      2.061      0.039       0.109       4.350
# ISO                    0.0583      0.487      0.120      0.905      -0.896       1.013
# Babip                  0.4659      0.456      1.022      0.307      -0.428       1.360
# RC                    -2.2924      0.428     -5.353      0.000      -3.132      -1.453
# K                      0.0150      0.005      2.965      0.003       0.005       0.025
# BB                    -0.3547      0.269     -1.317      0.188      -0.882       0.173
# RBI                   -0.0071      0.005     -1.489      0.136      -0.016       0.002
# K/B                   -0.4989      0.129     -3.862      0.000      -0.752      -0.246
# HR                     0.0717      0.054      1.332      0.183      -0.034       0.177
# PitH                  -1.6414      0.642     -2.558      0.011      -2.899      -0.384
# PitOBP                 6.6403      5.213      1.274      0.203      -3.576      16.857
# PitSLG                 4.9083      5.814      0.844      0.399      -6.487      16.304
# PitOPS               -10.6695     10.610     -1.006      0.315     -31.464      10.125
# PitHR                 -0.0779      0.065     -1.195      0.232      -0.206       0.050
# ERA                    0.3043      0.153      1.989      0.047       0.005       0.604
# PitB                  -0.9256      0.263     -3.519      0.000      -1.441      -0.410
# PitK                   2.1486      1.160      1.852      0.064      -0.125       4.423
# PitK/B                -1.6605      1.136     -1.462      0.144      -3.887       0.566
# WHIP                   0.1782      0.844      0.211      0.833      -1.476       1.833
# 1d_home_attendance    -0.0454      0.060     -0.758      0.449      -0.163       0.072
# ParkFactors           -0.2445      0.122     -1.999      0.046      -0.484      -0.005
# ======================================================================================
# Train accuracy =  0.5626339550367094
# Test accuracy =  0.5866935483870968

# %%
num_thread = 8
# num of cpu 
param ={'num_leaves':[4,6,8,10,20],'max_depth':[-1,3,6,9,12,15]}
lgb =LGBMClassifier()
lgb_clf = GridSearchCV(lgb,param,scoring='accuracy',n_jobs=num_thread)
lgb_results = lgb_clf.fit(X_train, y_train.values.ravel(), eval_metric=['logloss'],eval_set=[(X_test, y_test.values.ravel())],callbacks=[lightgbm.early_stopping(10, verbose=0)])

train_score = lgb_results.score(X_train, y_train)
test_score = lgb_results.score(X_test, y_test)
print(lgb_results.best_params_)
print(test_score)

rf_param ={'min_samples_split':[4,6,8,10,20],'max_depth':[-1,3,6,9,12,15]}
rf =RandomForestClassifier()
rf_clf = GridSearchCV(rf,rf_param,scoring='accuracy',n_jobs=num_thread)
rf_results = rf_clf.fit(X_train,  y_train.values.ravel())


train_score = rf_results.score(X_train, y_train)
test_score = rf_results.score(X_test, y_test)
print(rf_results.best_params_)
print(test_score)

param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0] 
svm_param  = [{'C': param_range, 'kernel': ['linear']}, {'C': param_range, 'gamma': param_range, 'kernel': ['rbf']}]
svm_model =svm.SVC()
svm_clf = GridSearchCV(estimator=svm_model,param_grid=svm_param,scoring='accuracy',n_jobs=num_thread,verbose=0)
svm_results = svm_clf.fit(X_train, y_train.values.ravel())

train_score = svm_results.score(X_train, y_train)
test_score = svm_results.score(X_test, y_test)
print(svm_results.best_params_)
print(test_score)
# Out:
# [1]	valid_0's binary_logloss: 0.689655
# [2]	valid_0's binary_logloss: 0.688711
# [3]	valid_0's binary_logloss: 0.68761
# [4]	valid_0's binary_logloss: 0.686368
# [5]	valid_0's binary_logloss: 0.685587
# [6]	valid_0's binary_logloss: 0.684723
# [7]	valid_0's binary_logloss: 0.684231
# [8]	valid_0's binary_logloss: 0.684032
# [9]	valid_0's binary_logloss: 0.682867
# [10]	valid_0's binary_logloss: 0.681975
# [11]	valid_0's binary_logloss: 0.681336
# [12]	valid_0's binary_logloss: 0.680472
# [13]	valid_0's binary_logloss: 0.679823
# [14]	valid_0's binary_logloss: 0.679087
# [15]	valid_0's binary_logloss: 0.678627
# [16]	valid_0's binary_logloss: 0.678342
# [17]	valid_0's binary_logloss: 0.677898
# [18]	valid_0's binary_logloss: 0.677316
# [19]	valid_0's binary_logloss: 0.676848
# [20]	valid_0's binary_logloss: 0.67665
# [21]	valid_0's binary_logloss: 0.676365
# [22]	valid_0's binary_logloss: 0.675905
# [23]	valid_0's binary_logloss: 0.675556
# [24]	valid_0's binary_logloss: 0.674956
# [25]	valid_0's binary_logloss: 0.674799
# [26]	valid_0's binary_logloss: 0.674808
# [27]	valid_0's binary_logloss: 0.67475
# [28]	valid_0's binary_logloss: 0.674576
# [29]	valid_0's binary_logloss: 0.674411
# [30]	valid_0's binary_logloss: 0.674135
# [31]	valid_0's binary_logloss: 0.67451
# [32]	valid_0's binary_logloss: 0.674305
# [33]	valid_0's binary_logloss: 0.674261
# [34]	valid_0's binary_logloss: 0.674224
# [35]	valid_0's binary_logloss: 0.674121
# [36]	valid_0's binary_logloss: 0.6738
# [37]	valid_0's binary_logloss: 0.674239
# [38]	valid_0's binary_logloss: 0.674234
# [39]	valid_0's binary_logloss: 0.674054
# [40]	valid_0's binary_logloss: 0.67405
# [41]	valid_0's binary_logloss: 0.673828
# [42]	valid_0's binary_logloss: 0.673825
# [43]	valid_0's binary_logloss: 0.6738
# [44]	valid_0's binary_logloss: 0.674338
# [45]	valid_0's binary_logloss: 0.674065
# [46]	valid_0's binary_logloss: 0.673691
# [47]	valid_0's binary_logloss: 0.673631
# [48]	valid_0's binary_logloss: 0.673632
# [49]	valid_0's binary_logloss: 0.673572
# [50]	valid_0's binary_logloss: 0.673706
# [51]	valid_0's binary_logloss: 0.673563
# [52]	valid_0's binary_logloss: 0.673574
# [53]	valid_0's binary_logloss: 0.673156
# [54]	valid_0's binary_logloss: 0.673136
# [55]	valid_0's binary_logloss: 0.673101
# [56]	valid_0's binary_logloss: 0.673097
# [57]	valid_0's binary_logloss: 0.672892
# [58]	valid_0's binary_logloss: 0.673716
# [59]	valid_0's binary_logloss: 0.673735
# [60]	valid_0's binary_logloss: 0.673545
# [61]	valid_0's binary_logloss: 0.673498
# [62]	valid_0's binary_logloss: 0.673482
# [63]	valid_0's binary_logloss: 0.673291
# [64]	valid_0's binary_logloss: 0.673213
# [65]	valid_0's binary_logloss: 0.673244
# [66]	valid_0's binary_logloss: 0.673296
# [67]	valid_0's binary_logloss: 0.673227
# {'max_depth': -1, 'num_leaves': 4}
# 0.5783326621022956
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a0c7fe3f3605> in <module>()
#      14 rf =RandomForestClassifier()
#      15 rf_clf = GridSearchCV(rf,rf_param,scoring='accuracy',n_jobs=num_thread)
# ---> 16 rf_results = rf_clf.fit(X_train,  y_train.values.ravel())
#      17
#      18
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     849                     )
#     850                     for (cand_idx, parameters), (split_idx, (train, test)) in product(
# --> 851                         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852                     )
#     853                 )
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
# Requirements:
# !pip install rtdl
# !pip install libzero==0.0.4

from typing import Any, Dict

import numpy as np
import rtdl
import scipy.special
import sklearn.datasets
import sklearn.metrics
import sklearn.model_selection
import sklearn.preprocessing
import torch
import torch.nn as nn
import torch.nn.functional as F
import zero

#device = torch.device('cpu')

device = torch.device("cuda:0")
# Docs: https://yura52.github.io/zero/0.0.4/reference/api/zero.improve_reproducibility.html
zero.improve_reproducibility(seed=123456)
# Out:
# Requirement already satisfied: rtdl in /usr/local/lib/python3.7/dist-packages (0.0.13)
# Requirement already satisfied: torch<2,>=1.7 in /usr/local/lib/python3.7/dist-packages (from rtdl) (1.11.0+cu113)
# Requirement already satisfied: numpy<2,>=1.18 in /usr/local/lib/python3.7/dist-packages (from rtdl) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<2,>=1.7->rtdl) (4.2.0)
# Requirement already satisfied: libzero==0.0.4 in /usr/local/lib/python3.7/dist-packages (0.0.4)
# Requirement already satisfied: numpy<2,>=1.17 in /usr/local/lib/python3.7/dist-packages (from libzero==0.0.4) (1.21.6)
# Requirement already satisfied: tqdm<5,>=4.0 in /usr/local/lib/python3.7/dist-packages (from libzero==0.0.4) (4.64.0)
# Requirement already satisfied: torch<2,>=1.6 in /usr/local/lib/python3.7/dist-packages (from libzero==0.0.4) (1.11.0+cu113)
# Requirement already satisfied: pynvml<9,>=8.0 in /usr/local/lib/python3.7/dist-packages (from libzero==0.0.4) (8.0.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<2,>=1.6->libzero==0.0.4) (4.2.0)
# 123456

# %%
# # !!! NOTE !!! The dataset splits, preprocessing and other details are
# # significantly different from those used in the
# # paper "Revisiting Deep Learning Models for Tabular Data",
# # so the results will be different from the reported in the paper.

# dataset = sklearn.datasets.fetch_california_housing()
# task_type = 'regression'

# # dataset = sklearn.datasets.fetch_covtype()
# # task_type = 'multiclass'

# assert task_type in ['binclass', 'multiclass', 'regression']

# X_all = dataset['data'].astype('float32')
# y_all = dataset['target'].astype('float32' if task_type == 'regression' else 'int64')
# if task_type != 'regression':
#     y_all = sklearn.preprocessing.LabelEncoder().fit_transform(y_all).astype('int64')
# n_classes = int(max(y_all)) + 1 if task_type == 'multiclass' else None

# X = {}
# y = {}
# X['train'], X['test'], y['train'], y['test'] = sklearn.model_selection.train_test_split(
#     X_all, y_all, train_size=0.8
# )
# X['train'], X['val'], y['train'], y['val'] = sklearn.model_selection.train_test_split(
#     X['train'], y['train'], train_size=0.8
# )

# # not the best way to preprocess features, but enough for the demonstration
# preprocess = sklearn.preprocessing.StandardScaler().fit(X['train'])
# X = {
#     k: torch.tensor(preprocess.fit_transform(v), device=device)
#     for k, v in X.items()
# }
# y = {k: torch.tensor(v, device=device) for k, v in y.items()}

# # !!! CRUCIAL for neural networks when solving regression problems !!!
# if task_type == 'regression':
#     y_mean = y['train'].mean().item()
#     y_std = y['train'].std().item()
#     y = {k: (v - y_mean) / y_std for k, v in y.items()}
# else:
#     y_std = y_mean = None

# if task_type != 'multiclass':
#     y = {k: v.float() for k, v in y.items()}

# %%
X_train.shape

X = {}
y = {}

# X_train = train[x_cols]
# y_train = train[y_cols]*1

# X_test = test[x_cols]
# y_test = test[y_cols]*1
print(y_train)
y_train = sklearn.preprocessing.LabelEncoder().fit_transform(y_train).astype('int64')
y_test = sklearn.preprocessing.LabelEncoder().fit_transform(y_test).astype('int64')

print(y_train)

X['train']=X_train
X['test']=X_test
y['train']=y_train
y['test']=y_test


# not the best way to preprocess features, but enough for the demonstration
preprocess = sklearn.preprocessing.StandardScaler().fit(X['train'])
X = {
    k: torch.tensor(preprocess.fit_transform(v), device=device)
    for k, v in X.items()
}
y = {k: torch.tensor(v, device=device) for k, v in y.items()}

print(X_train)
X['train']=torch.tensor(X['train'],dtype=torch.float32)
X['test']=torch.tensor(X['test'],dtype=torch.float32)
X['train']

X['train'], X['val'], y['train'], y['val'] = sklearn.model_selection.train_test_split(
    X['train'], y['train'], train_size=0.8
)
# Out:
#        _team_won?_x
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 0
# ...             ...
# 24385             0
# 24386             1
# 24387             0
# 24388             0
# 24389             0
#
# [21929 rows x 1 columns]
# [1 1 1 ... 0 0 0]
#               H       OBP       SLG       ISO     Babip        RC          K  \
# 0      0.943219  1.116067  0.948231  0.953428  0.981830  1.044089  34.055556
# 1      1.064780  1.172302  1.037013  1.010039  1.100000  1.206117  24.000000
# 2      1.022395  1.168678  0.931633  0.854571  1.050847  1.042585  18.676471
# 3      1.047315  1.194011  0.975034  0.911630  1.060606  1.164231  16.435897
# 4      1.254523  1.194784  1.085205  0.937387  1.107602  1.392407  10.534884
# ...         ...       ...       ...       ...       ...       ...        ...
# 24385  1.055954  0.985154  1.005238  0.962307  1.006109  1.018790   2.019090
# 24386  0.963683  0.905980  0.862859  0.778234  0.934953  0.809477   2.172012
# 24387  0.962831  0.905332  0.864636  0.781910  0.934315  0.810598   2.153736
# 24388  0.961255  0.904913  0.858034  0.771925  0.929834  0.803647   2.138810
# 24389  1.043341  0.977070  0.984771  0.935836  0.993932  0.988758   1.940028
#
#              BB        RBI       K/B  ...    PitSLG    PitOPS     PitHR  \
# 0      1.721039  25.923077  0.875861  ...  0.818612  0.808309  0.737860
# 1      1.453514  24.285714  0.971514  ...  0.975626  0.954502  0.840405
# 2      1.607529  18.157895  0.857734  ...  0.989182  0.973219  0.878311
# 3      1.625470  17.600000  0.837346  ...  0.936968  0.928338  0.761796
# 4      1.045436  19.776224  0.889437  ...  0.851746  0.866811  0.742958
# ...         ...        ...       ...  ...       ...       ...       ...
# 24385  0.829289   2.408022  1.096765  ...  1.113707  1.120236  1.016212
# 24386  0.779283   1.822785  1.284623  ...  1.111688  1.122834  1.005928
# 24387  0.779489   1.821317  1.283125  ...  1.108799  1.120174  0.994976
# 24388  0.780243   1.788344  1.281472  ...  1.116195  1.126829  1.008656
# 24389  0.829288   2.194118  1.105566  ...  1.133918  1.138806  1.040637
#
#             ERA      PitB      PitK    PitK/B      WHIP  1d_home_attendance  \
# 0      1.072209  0.561710  1.502693  1.713504  0.800867               1.013
# 1      1.408993  0.683701  1.276285  1.382828  0.968160               0.982
# 2      1.238752  0.691241  1.114530  1.204065  0.992963               0.981
# 3      1.403666  0.647749  1.136711  1.247527  0.960536               0.984
# 4      1.718138  0.705758  1.117734  1.210413  0.940832               0.996
# ...         ...       ...       ...       ...       ...                 ...
# 24385  1.098550  1.340480  0.898379  0.853822  1.095996               0.885
# 24386  0.841902  1.317719  0.866645  0.826794  1.103814               0.895
# 24387  0.845678  1.300096  0.868539  0.830136  1.101584               0.937
# 24388  0.835479  1.321620  0.867539  0.827292  1.106599               0.956
# 24389  1.049204  1.365365  0.882453  0.836282  1.110247               0.897
#
#        ParkFactors
# 0            1.063
# 1            1.063
# 2            1.063
# 3            1.063
# 4            1.063
# ...            ...
# 24385        0.905
# 24386        0.905
# 24387        0.905
# 24388        0.905
# 24389        0.905
#
# [21929 rows x 23 columns]

# %%
task_type ='binclass'
d_out = 1

model = rtdl.MLP.make_baseline(
    d_in=X_train.shape[1],
    d_layers=[128, 256, 128],
    dropout=0.1,
    d_out=d_out,
)
lr = 0.001
weight_decay = 0.0

# model = rtdl.ResNet.make_baseline(
#     d_in=X_all.shape[1],
#     d_main=128,
#     d_intermidiate=256,
#     dropout_first=0.2,
#     dropout_second=0.0,
#     n_blocks=2,
#     d_out=d_out,
# )
# lr = 0.001
# weight_decay = 0.0

# model = rtdl.FTTransformer.make_default(
#     n_num_features=X_all.shape[1],
#     cat_cardinalities=None,
#     last_layer_query_idx=[-1],  # it makes the model faster and does NOT affect its output
#     d_out=d_out,
# )

# === ABOUT CATEGORICAL FEATURES ===
# IF you use MLP, ResNet or any other simple feed-forward model (NOT transformer-based model)
# AND there are categorical features
# THEN you have to implement a wrapper that handles categorical features.
# The example below demonstrates how it can be achieved using rtdl.CategoricalFeatureTokenizer.
# ==================================
# 1. When you have both numerical and categorical features, you should prepare you data like this:
#    (X_num<float32>, X_cat<int64>) instead of X<float32>
#    Each column in X_cat should contain values within the range from 0 to <(the number of unique values in column) - 1>;
#    use sklean.preprocessing.OrdinalEncoder to achieve this;
# 2. Prepare a list of so called "cardinalities":
#    cardinalities[i] = <the number of unique values of the i-th categorical feature>
# 3. See the commented example below and adapt it for your needs.
#
# class Model(nn.Module):
#     def __init__(
#         self,
#         n_num_features: int,
#         cat_tokenizer: rtdl.CategoricalFeatureTokenizer,
#         mlp_kwargs: Dict[str, Any],
#     ):
#         super().__init__()
#         self.cat_tokenizer = cat_tokenizer
#         self.model = rtdl.MLP.make_baseline(
#             d_in=n_num_features + cat_tokenizer.n_tokens * cat_tokenizer.d_token,
#             **mlp_kwargs,
#         )
#
#     def forward(self, x_num, x_cat):
#         return self.model(
#             torch.cat([x_num, self.cat_tokenizer(x_cat).flatten(1, -1)], dim=1)
#         )
#
# model = Model(
#     # `None` means "Do not transform numerical features"
#     # `d_token` is the size of embedding for ONE categorical feature
#     X_num_all.shape[1],
#     rtdl.CategoricalFeatureTokenizer(cardinalities, d_token, True, 'uniform'),
#     mlp_kwargs,
# )
# Then the model should be used as `model(x_num, x_cat)` instead of of `model(x)`.

model.to(device)
optimizer = (
    model.make_default_optimizer()
    if isinstance(model, rtdl.FTTransformer)
    else torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
)
loss_fn = (
    F.binary_cross_entropy_with_logits
    if task_type == 'binclass'
    else F.cross_entropy
    if task_type == 'multiclass'
    else F.mse_loss
)

# %%
def apply_model(x_num, x_cat=None):
    if isinstance(model, rtdl.FTTransformer):
        return model(x_num, x_cat)
    elif isinstance(model, (rtdl.MLP, rtdl.ResNet)):
        assert x_cat is None
        return model(x_num)
    else:
        raise NotImplementedError(
            f'Looks like you are using a custom model: {type(model)}.'
            ' Then you have to implement this branch first.'
        )


@torch.no_grad()
def evaluate(part):
    model.eval()
    prediction = []
    for batch in zero.iter_batches(X[part], 1024):
        prediction.append(apply_model(batch))
    prediction = torch.cat(prediction).squeeze(1).cpu().numpy()
    target = y[part].cpu().numpy()

    if task_type == 'binclass':
        prediction = np.round(scipy.special.expit(prediction))
        score = sklearn.metrics.accuracy_score(target, prediction)
    elif task_type == 'multiclass':
        prediction = prediction.argmax(1)
        score = sklearn.metrics.accuracy_score(target, prediction)
    else:
        assert task_type == 'regression'
        score = sklearn.metrics.mean_squared_error(target, prediction) ** 0.5 * y_std
    return score


# Create a dataloader for batches of indices
# Docs: https://yura52.github.io/zero/reference/api/zero.data.IndexLoader.html
batch_size = 256
train_loader = zero.data.IndexLoader(len(X['train']), batch_size, device=device)

# Create a progress tracker for early stopping
# Docs: https://yura52.github.io/zero/reference/api/zero.ProgressTracker.html
progress = zero.ProgressTracker(patience=100)

print(f'Test score before training: {evaluate("test"):.4f}')
# Out:
# Test score before training: 0.5319

# %%
n_epochs = 2000
report_frequency = len(X['train']) // batch_size // 5
myloss=[]
mytestaccuracy=[]
myvalaccuracy=[]
len_trainloader=len(train_loader)
for epoch in range(1, n_epochs + 1):
    avg_loss=0
    for iteration, batch_idx in enumerate(train_loader):
        model.train()
        optimizer.zero_grad()
        x_batch = X['train'][batch_idx]
        y_batch = y['train'][batch_idx]
        loss = loss_fn(apply_model(x_batch).squeeze(1), y_batch.float())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()
    avg_loss=avg_loss / len_trainloader
    myloss.append(avg_loss)
    val_score = evaluate('val')
    myvalaccuracy.append(val_score)
    test_score = evaluate('test')
    mytestaccuracy.append(test_score)
    print(f'Epoch {epoch:03d} | loss: {avg_loss:.4f} | Validation score: {val_score:.4f} | Test score: {test_score:.4f}')
    # progress.update((-1 if task_type == 'regression' else 1) * val_score)
    # if progress.success:
    #     print(' <<< BEST VALIDATION EPOCH', end='')
    # print()
    # if progress.fail:
    #     break
# Out:
# Epoch 001 | loss: 0.6857 | Validation score: 0.5620 | Test score: 0.5940
# Epoch 002 | loss: 0.6829 | Validation score: 0.5602 | Test score: 0.5964
# Epoch 003 | loss: 0.6823 | Validation score: 0.5595 | Test score: 0.5944
# Epoch 004 | loss: 0.6819 | Validation score: 0.5611 | Test score: 0.5931
# Epoch 005 | loss: 0.6807 | Validation score: 0.5534 | Test score: 0.5944
# Epoch 006 | loss: 0.6807 | Validation score: 0.5604 | Test score: 0.5915
# Epoch 007 | loss: 0.6792 | Validation score: 0.5593 | Test score: 0.5919
# Epoch 008 | loss: 0.6791 | Validation score: 0.5588 | Test score: 0.5883
# Epoch 009 | loss: 0.6778 | Validation score: 0.5577 | Test score: 0.5855
# Epoch 010 | loss: 0.6764 | Validation score: 0.5570 | Test score: 0.5931
# Epoch 011 | loss: 0.6755 | Validation score: 0.5579 | Test score: 0.5907
# Epoch 012 | loss: 0.6735 | Validation score: 0.5549 | Test score: 0.5843
# Epoch 013 | loss: 0.6733 | Validation score: 0.5524 | Test score: 0.5778
# Epoch 014 | loss: 0.6706 | Validation score: 0.5547 | Test score: 0.5746
# Epoch 015 | loss: 0.6707 | Validation score: 0.5552 | Test score: 0.5762
# Epoch 016 | loss: 0.6670 | Validation score: 0.5502 | Test score: 0.5778
# Epoch 017 | loss: 0.6649 | Validation score: 0.5495 | Test score: 0.5750
# Epoch 018 | loss: 0.6640 | Validation score: 0.5422 | Test score: 0.5742
# Epoch 019 | loss: 0.6597 | Validation score: 0.5483 | Test score: 0.5746
# Epoch 020 | loss: 0.6572 | Validation score: 0.5456 | Test score: 0.5754
# Epoch 021 | loss: 0.6542 | Validation score: 0.5463 | Test score: 0.5621
# Epoch 022 | loss: 0.6515 | Validation score: 0.5413 | Test score: 0.5661
# Epoch 023 | loss: 0.6494 | Validation score: 0.5349 | Test score: 0.5641
# Epoch 024 | loss: 0.6473 | Validation score: 0.5340 | Test score: 0.5698
# Epoch 025 | loss: 0.6457 | Validation score: 0.5351 | Test score: 0.5698
# Epoch 026 | loss: 0.6415 | Validation score: 0.5328 | Test score: 0.5641
# Epoch 027 | loss: 0.6400 | Validation score: 0.5301 | Test score: 0.5649
# Epoch 028 | loss: 0.6356 | Validation score: 0.5376 | Test score: 0.5613
# Epoch 029 | loss: 0.6351 | Validation score: 0.5319 | Test score: 0.5673
# Epoch 030 | loss: 0.6332 | Validation score: 0.5369 | Test score: 0.5528
# Epoch 031 | loss: 0.6309 | Validation score: 0.5337 | Test score: 0.5480
# Epoch 032 | loss: 0.6281 | Validation score: 0.5353 | Test score: 0.5548
# Epoch 033 | loss: 0.6237 | Validation score: 0.5342 | Test score: 0.5500
# Epoch 034 | loss: 0.6220 | Validation score: 0.5353 | Test score: 0.5468
# Epoch 035 | loss: 0.6193 | Validation score: 0.5347 | Test score: 0.5577
# Epoch 036 | loss: 0.6171 | Validation score: 0.5278 | Test score: 0.5573
# Epoch 037 | loss: 0.6149 | Validation score: 0.5365 | Test score: 0.5536
# Epoch 038 | loss: 0.6107 | Validation score: 0.5372 | Test score: 0.5597
# Epoch 039 | loss: 0.6086 | Validation score: 0.5269 | Test score: 0.5601
# Epoch 040 | loss: 0.6063 | Validation score: 0.5301 | Test score: 0.5524
# Epoch 041 | loss: 0.6048 | Validation score: 0.5214 | Test score: 0.5520
# Epoch 042 | loss: 0.5998 | Validation score: 0.5315 | Test score: 0.5476
# Epoch 043 | loss: 0.5967 | Validation score: 0.5319 | Test score: 0.5548
# Epoch 044 | loss: 0.5972 | Validation score: 0.5312 | Test score: 0.5577
# Epoch 045 | loss: 0.5927 | Validation score: 0.5294 | Test score: 0.5492
# Epoch 046 | loss: 0.5934 | Validation score: 0.5271 | Test score: 0.5577
# Epoch 047 | loss: 0.5920 | Validation score: 0.5299 | Test score: 0.5375
# Epoch 048 | loss: 0.5878 | Validation score: 0.5324 | Test score: 0.5484
# Epoch 049 | loss: 0.5841 | Validation score: 0.5271 | Test score: 0.5468
# Epoch 050 | loss: 0.5860 | Validation score: 0.5292 | Test score: 0.5423
# Epoch 051 | loss: 0.5790 | Validation score: 0.5267 | Test score: 0.5484
# Epoch 052 | loss: 0.5806 | Validation score: 0.5239 | Test score: 0.5480
# Epoch 053 | loss: 0.5798 | Validation score: 0.5283 | Test score: 0.5548
# Epoch 054 | loss: 0.5712 | Validation score: 0.5235 | Test score: 0.5456
# Epoch 055 | loss: 0.5747 | Validation score: 0.5335 | Test score: 0.5472
# Epoch 056 | loss: 0.5708 | Validation score: 0.5280 | Test score: 0.5431
# Epoch 057 | loss: 0.5685 | Validation score: 0.5337 | Test score: 0.5335
# Epoch 058 | loss: 0.5722 | Validation score: 0.5303 | Test score: 0.5415
# Epoch 059 | loss: 0.5639 | Validation score: 0.5296 | Test score: 0.5444
# Epoch 060 | loss: 0.5657 | Validation score: 0.5294 | Test score: 0.5423
# Epoch 061 | loss: 0.5587 | Validation score: 0.5267 | Test score: 0.5427
# Epoch 062 | loss: 0.5597 | Validation score: 0.5321 | Test score: 0.5339
# Epoch 063 | loss: 0.5601 | Validation score: 0.5294 | Test score: 0.5306
# Epoch 064 | loss: 0.5532 | Validation score: 0.5301 | Test score: 0.5395
# Epoch 065 | loss: 0.5573 | Validation score: 0.5287 | Test score: 0.5347
# Epoch 066 | loss: 0.5541 | Validation score: 0.5321 | Test score: 0.5488
# Epoch 067 | loss: 0.5483 | Validation score: 0.5335 | Test score: 0.5452
# Epoch 068 | loss: 0.5489 | Validation score: 0.5331 | Test score: 0.5391
# Epoch 069 | loss: 0.5509 | Validation score: 0.5269 | Test score: 0.5367
# Epoch 070 | loss: 0.5455 | Validation score: 0.5287 | Test score: 0.5431
# Epoch 071 | loss: 0.5416 | Validation score: 0.5335 | Test score: 0.5452
# Epoch 072 | loss: 0.5421 | Validation score: 0.5294 | Test score: 0.5298
# Epoch 073 | loss: 0.5448 | Validation score: 0.5333 | Test score: 0.5294
# Epoch 074 | loss: 0.5374 | Validation score: 0.5303 | Test score: 0.5286
# Epoch 075 | loss: 0.5387 | Validation score: 0.5290 | Test score: 0.5444
# Epoch 076 | loss: 0.5376 | Validation score: 0.5290 | Test score: 0.5351
# Epoch 077 | loss: 0.5408 | Validation score: 0.5328 | Test score: 0.5387
# Epoch 078 | loss: 0.5334 | Validation score: 0.5287 | Test score: 0.5427
# Epoch 079 | loss: 0.5318 | Validation score: 0.5306 | Test score: 0.5435
# Epoch 080 | loss: 0.5317 | Validation score: 0.5280 | Test score: 0.5435
# Epoch 081 | loss: 0.5377 | Validation score: 0.5306 | Test score: 0.5468
# Epoch 082 | loss: 0.5280 | Validation score: 0.5299 | Test score: 0.5347
# Epoch 083 | loss: 0.5257 | Validation score: 0.5324 | Test score: 0.5516
# Epoch 084 | loss: 0.5241 | Validation score: 0.5340 | Test score: 0.5444
# Epoch 085 | loss: 0.5231 | Validation score: 0.5324 | Test score: 0.5444
# Epoch 086 | loss: 0.5235 | Validation score: 0.5253 | Test score: 0.5363
# Epoch 087 | loss: 0.5209 | Validation score: 0.5303 | Test score: 0.5395
# Epoch 088 | loss: 0.5227 | Validation score: 0.5271 | Test score: 0.5427
# Epoch 089 | loss: 0.5188 | Validation score: 0.5363 | Test score: 0.5484
# Epoch 090 | loss: 0.5188 | Validation score: 0.5285 | Test score: 0.5423
# Epoch 091 | loss: 0.5168 | Validation score: 0.5308 | Test score: 0.5298
# Epoch 092 | loss: 0.5149 | Validation score: 0.5283 | Test score: 0.5427
# Epoch 093 | loss: 0.5156 | Validation score: 0.5331 | Test score: 0.5375
# Epoch 094 | loss: 0.5098 | Validation score: 0.5328 | Test score: 0.5488
# Epoch 095 | loss: 0.5118 | Validation score: 0.5356 | Test score: 0.5335
# Epoch 096 | loss: 0.5112 | Validation score: 0.5310 | Test score: 0.5375
# Epoch 097 | loss: 0.5132 | Validation score: 0.5333 | Test score: 0.5480
# Epoch 098 | loss: 0.5086 | Validation score: 0.5287 | Test score: 0.5367
# Epoch 099 | loss: 0.5132 | Validation score: 0.5301 | Test score: 0.5444
# Epoch 100 | loss: 0.5062 | Validation score: 0.5285 | Test score: 0.5327
# Epoch 101 | loss: 0.5069 | Validation score: 0.5290 | Test score: 0.5532
# Epoch 102 | loss: 0.5086 | Validation score: 0.5296 | Test score: 0.5472
# Epoch 103 | loss: 0.5047 | Validation score: 0.5244 | Test score: 0.5407
# Epoch 104 | loss: 0.5025 | Validation score: 0.5335 | Test score: 0.5323
# Epoch 105 | loss: 0.5009 | Validation score: 0.5262 | Test score: 0.5371
# Epoch 106 | loss: 0.5001 | Validation score: 0.5292 | Test score: 0.5419
# Epoch 107 | loss: 0.4969 | Validation score: 0.5264 | Test score: 0.5435
# Epoch 108 | loss: 0.4986 | Validation score: 0.5285 | Test score: 0.5448
# Epoch 109 | loss: 0.5000 | Validation score: 0.5276 | Test score: 0.5310
# Epoch 110 | loss: 0.4967 | Validation score: 0.5296 | Test score: 0.5407
# Epoch 111 | loss: 0.4911 | Validation score: 0.5269 | Test score: 0.5278
# Epoch 112 | loss: 0.4965 | Validation score: 0.5308 | Test score: 0.5411
# Epoch 113 | loss: 0.4923 | Validation score: 0.5294 | Test score: 0.5335
# Epoch 114 | loss: 0.4980 | Validation score: 0.5269 | Test score: 0.5375
# Epoch 115 | loss: 0.4938 | Validation score: 0.5333 | Test score: 0.5343
# Epoch 116 | loss: 0.4912 | Validation score: 0.5255 | Test score: 0.5399
# Epoch 117 | loss: 0.4931 | Validation score: 0.5228 | Test score: 0.5262
# Epoch 118 | loss: 0.4890 | Validation score: 0.5251 | Test score: 0.5379
# Epoch 119 | loss: 0.4939 | Validation score: 0.5276 | Test score: 0.5423
# Epoch 120 | loss: 0.4868 | Validation score: 0.5264 | Test score: 0.5367
# Epoch 121 | loss: 0.4870 | Validation score: 0.5210 | Test score: 0.5323
# Epoch 122 | loss: 0.4794 | Validation score: 0.5274 | Test score: 0.5339
# Epoch 123 | loss: 0.4855 | Validation score: 0.5280 | Test score: 0.5306
# Epoch 124 | loss: 0.4870 | Validation score: 0.5278 | Test score: 0.5403
# Epoch 125 | loss: 0.4868 | Validation score: 0.5226 | Test score: 0.5234
# Epoch 126 | loss: 0.4827 | Validation score: 0.5219 | Test score: 0.5323
# Epoch 127 | loss: 0.4769 | Validation score: 0.5303 | Test score: 0.5339
# Epoch 128 | loss: 0.4799 | Validation score: 0.5285 | Test score: 0.5359
# Epoch 129 | loss: 0.4799 | Validation score: 0.5269 | Test score: 0.5431
# Epoch 130 | loss: 0.4762 | Validation score: 0.5287 | Test score: 0.5411
# Epoch 131 | loss: 0.4802 | Validation score: 0.5237 | Test score: 0.5327
# Epoch 132 | loss: 0.4776 | Validation score: 0.5290 | Test score: 0.5399
# Epoch 133 | loss: 0.4728 | Validation score: 0.5349 | Test score: 0.5202
# Epoch 134 | loss: 0.4813 | Validation score: 0.5262 | Test score: 0.5310
# Epoch 135 | loss: 0.4747 | Validation score: 0.5244 | Test score: 0.5327
# Epoch 136 | loss: 0.4684 | Validation score: 0.5326 | Test score: 0.5343
# Epoch 137 | loss: 0.4775 | Validation score: 0.5299 | Test score: 0.5387
# Epoch 138 | loss: 0.4716 | Validation score: 0.5324 | Test score: 0.5323
# Epoch 139 | loss: 0.4749 | Validation score: 0.5258 | Test score: 0.5335
# Epoch 140 | loss: 0.4712 | Validation score: 0.5319 | Test score: 0.5254
# Epoch 141 | loss: 0.4732 | Validation score: 0.5303 | Test score: 0.5262
# Epoch 142 | loss: 0.4707 | Validation score: 0.5337 | Test score: 0.5298
# Epoch 143 | loss: 0.4695 | Validation score: 0.5283 | Test score: 0.5198
# Epoch 144 | loss: 0.4733 | Validation score: 0.5228 | Test score: 0.5335
# Epoch 145 | loss: 0.4681 | Validation score: 0.5333 | Test score: 0.5242
# Epoch 146 | loss: 0.4666 | Validation score: 0.5271 | Test score: 0.5266
# Epoch 147 | loss: 0.4631 | Validation score: 0.5255 | Test score: 0.5302
# Epoch 148 | loss: 0.4719 | Validation score: 0.5271 | Test score: 0.5359
# Epoch 149 | loss: 0.4646 | Validation score: 0.5271 | Test score: 0.5375
# Epoch 150 | loss: 0.4633 | Validation score: 0.5264 | Test score: 0.5355
# Epoch 151 | loss: 0.4662 | Validation score: 0.5319 | Test score: 0.5319
# Epoch 152 | loss: 0.4580 | Validation score: 0.5258 | Test score: 0.5407
# Epoch 153 | loss: 0.4619 | Validation score: 0.5308 | Test score: 0.5278
# Epoch 154 | loss: 0.4624 | Validation score: 0.5242 | Test score: 0.5258
# Epoch 155 | loss: 0.4575 | Validation score: 0.5267 | Test score: 0.5226
# Epoch 156 | loss: 0.4589 | Validation score: 0.5237 | Test score: 0.5266
# Epoch 157 | loss: 0.4598 | Validation score: 0.5207 | Test score: 0.5190
# Epoch 158 | loss: 0.4590 | Validation score: 0.5196 | Test score: 0.5290
# Epoch 159 | loss: 0.4585 | Validation score: 0.5264 | Test score: 0.5226
# Epoch 160 | loss: 0.4589 | Validation score: 0.5301 | Test score: 0.5270
# Epoch 161 | loss: 0.4547 | Validation score: 0.5201 | Test score: 0.5262
# Epoch 162 | loss: 0.4561 | Validation score: 0.5269 | Test score: 0.5246
# Epoch 163 | loss: 0.4532 | Validation score: 0.5308 | Test score: 0.5165
# Epoch 164 | loss: 0.4580 | Validation score: 0.5269 | Test score: 0.5274
# Epoch 165 | loss: 0.4590 | Validation score: 0.5207 | Test score: 0.5278
# Epoch 166 | loss: 0.4542 | Validation score: 0.5319 | Test score: 0.5274
# Epoch 167 | loss: 0.4571 | Validation score: 0.5294 | Test score: 0.5230
# Epoch 168 | loss: 0.4542 | Validation score: 0.5306 | Test score: 0.5165
# Epoch 169 | loss: 0.4561 | Validation score: 0.5269 | Test score: 0.5089
# Epoch 170 | loss: 0.4576 | Validation score: 0.5294 | Test score: 0.5190
# Epoch 171 | loss: 0.4504 | Validation score: 0.5260 | Test score: 0.5089
# Epoch 172 | loss: 0.4501 | Validation score: 0.5255 | Test score: 0.5238
# Epoch 173 | loss: 0.4479 | Validation score: 0.5239 | Test score: 0.5052
# Epoch 174 | loss: 0.4490 | Validation score: 0.5292 | Test score: 0.5125
# Epoch 175 | loss: 0.4489 | Validation score: 0.5274 | Test score: 0.5133
# Epoch 176 | loss: 0.4490 | Validation score: 0.5253 | Test score: 0.5165
# Epoch 177 | loss: 0.4487 | Validation score: 0.5233 | Test score: 0.5194
# Epoch 178 | loss: 0.4454 | Validation score: 0.5294 | Test score: 0.5165
# Epoch 179 | loss: 0.4460 | Validation score: 0.5226 | Test score: 0.5185
# Epoch 180 | loss: 0.4461 | Validation score: 0.5226 | Test score: 0.5230
# Epoch 181 | loss: 0.4458 | Validation score: 0.5230 | Test score: 0.5230
# Epoch 182 | loss: 0.4443 | Validation score: 0.5230 | Test score: 0.5194
# Epoch 183 | loss: 0.4431 | Validation score: 0.5287 | Test score: 0.5210
# Epoch 184 | loss: 0.4473 | Validation score: 0.5331 | Test score: 0.5242
# Epoch 185 | loss: 0.4450 | Validation score: 0.5249 | Test score: 0.5161
# Epoch 186 | loss: 0.4388 | Validation score: 0.5333 | Test score: 0.5185
# Epoch 187 | loss: 0.4396 | Validation score: 0.5292 | Test score: 0.5190
# Epoch 188 | loss: 0.4410 | Validation score: 0.5271 | Test score: 0.5145
# Epoch 189 | loss: 0.4419 | Validation score: 0.5337 | Test score: 0.5198
# Epoch 190 | loss: 0.4414 | Validation score: 0.5301 | Test score: 0.5206
# Epoch 191 | loss: 0.4396 | Validation score: 0.5280 | Test score: 0.5145
# Epoch 192 | loss: 0.4391 | Validation score: 0.5210 | Test score: 0.5056
# Epoch 193 | loss: 0.4406 | Validation score: 0.5212 | Test score: 0.5161
# Epoch 194 | loss: 0.4414 | Validation score: 0.5226 | Test score: 0.5141
# Epoch 195 | loss: 0.4338 | Validation score: 0.5287 | Test score: 0.5141
# Epoch 196 | loss: 0.4384 | Validation score: 0.5253 | Test score: 0.5020
# Epoch 197 | loss: 0.4352 | Validation score: 0.5228 | Test score: 0.5153
# Epoch 198 | loss: 0.4343 | Validation score: 0.5274 | Test score: 0.5202
# Epoch 199 | loss: 0.4350 | Validation score: 0.5299 | Test score: 0.5165
# Epoch 200 | loss: 0.4324 | Validation score: 0.5210 | Test score: 0.5149
# Epoch 201 | loss: 0.4337 | Validation score: 0.5239 | Test score: 0.5198
# Epoch 202 | loss: 0.4324 | Validation score: 0.5253 | Test score: 0.5185
# Epoch 203 | loss: 0.4371 | Validation score: 0.5196 | Test score: 0.5210
# Epoch 204 | loss: 0.4337 | Validation score: 0.5280 | Test score: 0.5234
# Epoch 205 | loss: 0.4363 | Validation score: 0.5237 | Test score: 0.5169
# Epoch 206 | loss: 0.4301 | Validation score: 0.5262 | Test score: 0.5234
# Epoch 207 | loss: 0.4327 | Validation score: 0.5287 | Test score: 0.5246
# Epoch 208 | loss: 0.4310 | Validation score: 0.5230 | Test score: 0.5230
# Epoch 209 | loss: 0.4354 | Validation score: 0.5283 | Test score: 0.5190
# Epoch 210 | loss: 0.4353 | Validation score: 0.5258 | Test score: 0.5218
# Epoch 211 | loss: 0.4304 | Validation score: 0.5299 | Test score: 0.5222
# Epoch 212 | loss: 0.4258 | Validation score: 0.5176 | Test score: 0.5101
# Epoch 213 | loss: 0.4313 | Validation score: 0.5296 | Test score: 0.5117
# Epoch 214 | loss: 0.4254 | Validation score: 0.5262 | Test score: 0.5117
# Epoch 215 | loss: 0.4334 | Validation score: 0.5290 | Test score: 0.5133
# Epoch 216 | loss: 0.4239 | Validation score: 0.5260 | Test score: 0.5028
# Epoch 217 | loss: 0.4263 | Validation score: 0.5276 | Test score: 0.5097
# Epoch 218 | loss: 0.4290 | Validation score: 0.5223 | Test score: 0.5113
# Epoch 219 | loss: 0.4268 | Validation score: 0.5271 | Test score: 0.5210
# Epoch 220 | loss: 0.4300 | Validation score: 0.5255 | Test score: 0.5129
# Epoch 221 | loss: 0.4264 | Validation score: 0.5271 | Test score: 0.5185
# Epoch 222 | loss: 0.4267 | Validation score: 0.5226 | Test score: 0.5085
# Epoch 223 | loss: 0.4237 | Validation score: 0.5278 | Test score: 0.5093
# Epoch 224 | loss: 0.4232 | Validation score: 0.5276 | Test score: 0.5149
# Epoch 225 | loss: 0.4268 | Validation score: 0.5221 | Test score: 0.5157
# Epoch 226 | loss: 0.4257 | Validation score: 0.5198 | Test score: 0.5222
# Epoch 227 | loss: 0.4307 | Validation score: 0.5249 | Test score: 0.5351
# Epoch 228 | loss: 0.4230 | Validation score: 0.5239 | Test score: 0.5129
# Epoch 229 | loss: 0.4268 | Validation score: 0.5301 | Test score: 0.5141
# Epoch 230 | loss: 0.4271 | Validation score: 0.5290 | Test score: 0.5089
# Epoch 231 | loss: 0.4229 | Validation score: 0.5274 | Test score: 0.5125
# Epoch 232 | loss: 0.4237 | Validation score: 0.5278 | Test score: 0.5125
# Epoch 233 | loss: 0.4225 | Validation score: 0.5255 | Test score: 0.5121
# Epoch 234 | loss: 0.4223 | Validation score: 0.5255 | Test score: 0.5169
# Epoch 235 | loss: 0.4200 | Validation score: 0.5262 | Test score: 0.5077
# Epoch 236 | loss: 0.4215 | Validation score: 0.5319 | Test score: 0.5185
# Epoch 237 | loss: 0.4160 | Validation score: 0.5269 | Test score: 0.5181
# Epoch 238 | loss: 0.4246 | Validation score: 0.5255 | Test score: 0.5121
# Epoch 239 | loss: 0.4255 | Validation score: 0.5253 | Test score: 0.5149
# Epoch 240 | loss: 0.4210 | Validation score: 0.5280 | Test score: 0.5065
# Epoch 241 | loss: 0.4235 | Validation score: 0.5219 | Test score: 0.5157
# Epoch 242 | loss: 0.4165 | Validation score: 0.5203 | Test score: 0.5081
# Epoch 243 | loss: 0.4150 | Validation score: 0.5203 | Test score: 0.5109
# Epoch 244 | loss: 0.4199 | Validation score: 0.5235 | Test score: 0.5210
# Epoch 245 | loss: 0.4162 | Validation score: 0.5260 | Test score: 0.5133
# Epoch 246 | loss: 0.4206 | Validation score: 0.5173 | Test score: 0.5125
# Epoch 247 | loss: 0.4140 | Validation score: 0.5178 | Test score: 0.5113
# Epoch 248 | loss: 0.4209 | Validation score: 0.5246 | Test score: 0.5133
# Epoch 249 | loss: 0.4153 | Validation score: 0.5244 | Test score: 0.5149
# Epoch 250 | loss: 0.4116 | Validation score: 0.5251 | Test score: 0.5129
# Epoch 251 | loss: 0.4131 | Validation score: 0.5246 | Test score: 0.5032
# Epoch 252 | loss: 0.4147 | Validation score: 0.5219 | Test score: 0.4992
# Epoch 253 | loss: 0.4144 | Validation score: 0.5205 | Test score: 0.5024
# Epoch 254 | loss: 0.4105 | Validation score: 0.5267 | Test score: 0.5032
# Epoch 255 | loss: 0.4159 | Validation score: 0.5192 | Test score: 0.5141
# Epoch 256 | loss: 0.4114 | Validation score: 0.5178 | Test score: 0.5069
# Epoch 257 | loss: 0.4139 | Validation score: 0.5230 | Test score: 0.5121
# Epoch 258 | loss: 0.4105 | Validation score: 0.5271 | Test score: 0.5230
# Epoch 259 | loss: 0.4111 | Validation score: 0.5292 | Test score: 0.5125
# Epoch 260 | loss: 0.4133 | Validation score: 0.5276 | Test score: 0.5073
# Epoch 261 | loss: 0.4116 | Validation score: 0.5233 | Test score: 0.5085
# Epoch 262 | loss: 0.4117 | Validation score: 0.5294 | Test score: 0.5113
# Epoch 263 | loss: 0.4089 | Validation score: 0.5253 | Test score: 0.5141
# Epoch 264 | loss: 0.4107 | Validation score: 0.5269 | Test score: 0.5008
# Epoch 265 | loss: 0.4146 | Validation score: 0.5244 | Test score: 0.5125
# Epoch 266 | loss: 0.4165 | Validation score: 0.5280 | Test score: 0.5145
# Epoch 267 | loss: 0.4079 | Validation score: 0.5253 | Test score: 0.5121
# Epoch 268 | loss: 0.4089 | Validation score: 0.5264 | Test score: 0.5089
# Epoch 269 | loss: 0.4111 | Validation score: 0.5269 | Test score: 0.4956
# Epoch 270 | loss: 0.4055 | Validation score: 0.5276 | Test score: 0.5044
# Epoch 271 | loss: 0.4090 | Validation score: 0.5267 | Test score: 0.5044
# Epoch 272 | loss: 0.4063 | Validation score: 0.5333 | Test score: 0.5069
# Epoch 273 | loss: 0.4076 | Validation score: 0.5255 | Test score: 0.5097
# Epoch 274 | loss: 0.4036 | Validation score: 0.5221 | Test score: 0.5141
# Epoch 275 | loss: 0.4105 | Validation score: 0.5315 | Test score: 0.5056
# Epoch 276 | loss: 0.4089 | Validation score: 0.5249 | Test score: 0.5113
# Epoch 277 | loss: 0.4070 | Validation score: 0.5182 | Test score: 0.5024
# Epoch 278 | loss: 0.4095 | Validation score: 0.5312 | Test score: 0.5020
# Epoch 279 | loss: 0.4052 | Validation score: 0.5276 | Test score: 0.5153
# Epoch 280 | loss: 0.4048 | Validation score: 0.5205 | Test score: 0.5032
# Epoch 281 | loss: 0.4102 | Validation score: 0.5210 | Test score: 0.5121
# Epoch 282 | loss: 0.3991 | Validation score: 0.5251 | Test score: 0.5121
# Epoch 283 | loss: 0.4070 | Validation score: 0.5262 | Test score: 0.5185
# Epoch 284 | loss: 0.4008 | Validation score: 0.5262 | Test score: 0.5109
# Epoch 285 | loss: 0.4080 | Validation score: 0.5233 | Test score: 0.5185
# Epoch 286 | loss: 0.3952 | Validation score: 0.5228 | Test score: 0.5129
# Epoch 287 | loss: 0.4044 | Validation score: 0.5205 | Test score: 0.5157
# Epoch 288 | loss: 0.4035 | Validation score: 0.5212 | Test score: 0.5052
# Epoch 289 | loss: 0.4016 | Validation score: 0.5182 | Test score: 0.4996
# Epoch 290 | loss: 0.4048 | Validation score: 0.5189 | Test score: 0.5044
# Epoch 291 | loss: 0.4074 | Validation score: 0.5203 | Test score: 0.5121
# Epoch 292 | loss: 0.3987 | Validation score: 0.5185 | Test score: 0.5129
# Epoch 293 | loss: 0.4046 | Validation score: 0.5301 | Test score: 0.5077
# Epoch 294 | loss: 0.4004 | Validation score: 0.5237 | Test score: 0.5056
# Epoch 295 | loss: 0.4002 | Validation score: 0.5178 | Test score: 0.4940
# Epoch 296 | loss: 0.4013 | Validation score: 0.5228 | Test score: 0.4996
# Epoch 297 | loss: 0.4034 | Validation score: 0.5287 | Test score: 0.5085
# Epoch 298 | loss: 0.4022 | Validation score: 0.5239 | Test score: 0.5194
# Epoch 299 | loss: 0.4039 | Validation score: 0.5201 | Test score: 0.5161
# Epoch 300 | loss: 0.4035 | Validation score: 0.5230 | Test score: 0.5036
# Epoch 301 | loss: 0.3983 | Validation score: 0.5253 | Test score: 0.5028
# Epoch 302 | loss: 0.4016 | Validation score: 0.5249 | Test score: 0.5077
# Epoch 303 | loss: 0.3967 | Validation score: 0.5203 | Test score: 0.5133
# Epoch 304 | loss: 0.4022 | Validation score: 0.5212 | Test score: 0.5089
# Epoch 305 | loss: 0.3969 | Validation score: 0.5253 | Test score: 0.5125
# Epoch 306 | loss: 0.3980 | Validation score: 0.5242 | Test score: 0.4980
# Epoch 307 | loss: 0.4021 | Validation score: 0.5269 | Test score: 0.5024
# Epoch 308 | loss: 0.4020 | Validation score: 0.5221 | Test score: 0.5012
# Epoch 309 | loss: 0.3998 | Validation score: 0.5283 | Test score: 0.5089
# Epoch 310 | loss: 0.3990 | Validation score: 0.5280 | Test score: 0.4984
# Epoch 311 | loss: 0.4013 | Validation score: 0.5242 | Test score: 0.5121
# Epoch 312 | loss: 0.3986 | Validation score: 0.5214 | Test score: 0.5109
# Epoch 313 | loss: 0.3920 | Validation score: 0.5287 | Test score: 0.5137
# Epoch 314 | loss: 0.3948 | Validation score: 0.5262 | Test score: 0.5198
# Epoch 315 | loss: 0.4048 | Validation score: 0.5299 | Test score: 0.5177
# Epoch 316 | loss: 0.3996 | Validation score: 0.5242 | Test score: 0.5125
# Epoch 317 | loss: 0.3968 | Validation score: 0.5242 | Test score: 0.5032
# Epoch 318 | loss: 0.3942 | Validation score: 0.5239 | Test score: 0.5129
# Epoch 319 | loss: 0.3968 | Validation score: 0.5239 | Test score: 0.5077
# Epoch 320 | loss: 0.3951 | Validation score: 0.5255 | Test score: 0.5020
# Epoch 321 | loss: 0.4019 | Validation score: 0.5249 | Test score: 0.5060
# Epoch 322 | loss: 0.3928 | Validation score: 0.5296 | Test score: 0.5117
# Epoch 323 | loss: 0.3947 | Validation score: 0.5255 | Test score: 0.5089
# Epoch 324 | loss: 0.3922 | Validation score: 0.5306 | Test score: 0.5105
# Epoch 325 | loss: 0.3934 | Validation score: 0.5280 | Test score: 0.5048
# Epoch 326 | loss: 0.3892 | Validation score: 0.5217 | Test score: 0.5000
# Epoch 327 | loss: 0.3908 | Validation score: 0.5242 | Test score: 0.5052
# Epoch 328 | loss: 0.3933 | Validation score: 0.5221 | Test score: 0.5133
# Epoch 329 | loss: 0.3914 | Validation score: 0.5260 | Test score: 0.5040
# Epoch 330 | loss: 0.3889 | Validation score: 0.5276 | Test score: 0.5117
# Epoch 331 | loss: 0.3918 | Validation score: 0.5276 | Test score: 0.5173
# Epoch 332 | loss: 0.3928 | Validation score: 0.5233 | Test score: 0.5113
# Epoch 333 | loss: 0.3881 | Validation score: 0.5271 | Test score: 0.5145
# Epoch 334 | loss: 0.3934 | Validation score: 0.5283 | Test score: 0.5254
# Epoch 335 | loss: 0.3918 | Validation score: 0.5239 | Test score: 0.5125
# Epoch 336 | loss: 0.3874 | Validation score: 0.5267 | Test score: 0.5129
# Epoch 337 | loss: 0.3901 | Validation score: 0.5287 | Test score: 0.5238
# Epoch 338 | loss: 0.3967 | Validation score: 0.5262 | Test score: 0.5169
# Epoch 339 | loss: 0.3870 | Validation score: 0.5290 | Test score: 0.5085
# Epoch 340 | loss: 0.3877 | Validation score: 0.5262 | Test score: 0.5133
# Epoch 341 | loss: 0.3887 | Validation score: 0.5269 | Test score: 0.5129
# Epoch 342 | loss: 0.3910 | Validation score: 0.5303 | Test score: 0.5181
# Epoch 343 | loss: 0.3896 | Validation score: 0.5226 | Test score: 0.4984
# Epoch 344 | loss: 0.3906 | Validation score: 0.5312 | Test score: 0.5044
# Epoch 345 | loss: 0.3843 | Validation score: 0.5319 | Test score: 0.4996
# Epoch 346 | loss: 0.3908 | Validation score: 0.5201 | Test score: 0.4944
# Epoch 347 | loss: 0.3944 | Validation score: 0.5269 | Test score: 0.5109
# Epoch 348 | loss: 0.3862 | Validation score: 0.5223 | Test score: 0.5028
# Epoch 349 | loss: 0.3889 | Validation score: 0.5244 | Test score: 0.5085
# Epoch 350 | loss: 0.3863 | Validation score: 0.5285 | Test score: 0.5044
# Epoch 351 | loss: 0.3871 | Validation score: 0.5296 | Test score: 0.5145
# Epoch 352 | loss: 0.3865 | Validation score: 0.5299 | Test score: 0.5012
# Epoch 353 | loss: 0.3829 | Validation score: 0.5308 | Test score: 0.5044
# Epoch 354 | loss: 0.3849 | Validation score: 0.5251 | Test score: 0.5016
# Epoch 355 | loss: 0.3836 | Validation score: 0.5271 | Test score: 0.5012
# Epoch 356 | loss: 0.3866 | Validation score: 0.5299 | Test score: 0.4944
# Epoch 357 | loss: 0.3872 | Validation score: 0.5351 | Test score: 0.4972
# Epoch 358 | loss: 0.3907 | Validation score: 0.5228 | Test score: 0.5065
# Epoch 359 | loss: 0.3872 | Validation score: 0.5264 | Test score: 0.5024
# Epoch 360 | loss: 0.3878 | Validation score: 0.5230 | Test score: 0.4903
# Epoch 361 | loss: 0.3851 | Validation score: 0.5315 | Test score: 0.5032
# Epoch 362 | loss: 0.3874 | Validation score: 0.5264 | Test score: 0.4976
# Epoch 363 | loss: 0.3837 | Validation score: 0.5356 | Test score: 0.5077
# Epoch 364 | loss: 0.3822 | Validation score: 0.5267 | Test score: 0.5048
# Epoch 365 | loss: 0.3892 | Validation score: 0.5344 | Test score: 0.5044
# Epoch 366 | loss: 0.3838 | Validation score: 0.5230 | Test score: 0.5016
# Epoch 367 | loss: 0.3855 | Validation score: 0.5239 | Test score: 0.5012
# Epoch 368 | loss: 0.3817 | Validation score: 0.5230 | Test score: 0.4907
# Epoch 369 | loss: 0.3823 | Validation score: 0.5242 | Test score: 0.4968
# Epoch 370 | loss: 0.3829 | Validation score: 0.5274 | Test score: 0.5004
# Epoch 371 | loss: 0.3852 | Validation score: 0.5269 | Test score: 0.5089
# Epoch 372 | loss: 0.3829 | Validation score: 0.5228 | Test score: 0.5040
# Epoch 373 | loss: 0.3864 | Validation score: 0.5258 | Test score: 0.5056
# Epoch 374 | loss: 0.3830 | Validation score: 0.5269 | Test score: 0.5008
# Epoch 375 | loss: 0.3838 | Validation score: 0.5267 | Test score: 0.4956
# Epoch 376 | loss: 0.3852 | Validation score: 0.5276 | Test score: 0.5020
# Epoch 377 | loss: 0.3825 | Validation score: 0.5267 | Test score: 0.4988
# Epoch 378 | loss: 0.3864 | Validation score: 0.5278 | Test score: 0.5012
# Epoch 379 | loss: 0.3858 | Validation score: 0.5228 | Test score: 0.5032
# Epoch 380 | loss: 0.3908 | Validation score: 0.5249 | Test score: 0.5125
# Epoch 381 | loss: 0.3836 | Validation score: 0.5260 | Test score: 0.5004
# Epoch 382 | loss: 0.3839 | Validation score: 0.5214 | Test score: 0.5117
# Epoch 383 | loss: 0.3789 | Validation score: 0.5278 | Test score: 0.5157
# Epoch 384 | loss: 0.3825 | Validation score: 0.5269 | Test score: 0.5129
# Epoch 385 | loss: 0.3817 | Validation score: 0.5237 | Test score: 0.5137
# Epoch 386 | loss: 0.3793 | Validation score: 0.5274 | Test score: 0.5137
# Epoch 387 | loss: 0.3818 | Validation score: 0.5306 | Test score: 0.5113
# Epoch 388 | loss: 0.3839 | Validation score: 0.5308 | Test score: 0.5097
# Epoch 389 | loss: 0.3809 | Validation score: 0.5301 | Test score: 0.5077
# Epoch 390 | loss: 0.3825 | Validation score: 0.5301 | Test score: 0.5145
# Epoch 391 | loss: 0.3846 | Validation score: 0.5271 | Test score: 0.5065
# Epoch 392 | loss: 0.3831 | Validation score: 0.5303 | Test score: 0.5109
# Epoch 393 | loss: 0.3774 | Validation score: 0.5335 | Test score: 0.5093
# Epoch 394 | loss: 0.3765 | Validation score: 0.5278 | Test score: 0.5121
# Epoch 395 | loss: 0.3785 | Validation score: 0.5285 | Test score: 0.5105
# Epoch 396 | loss: 0.3747 | Validation score: 0.5244 | Test score: 0.5032
# Epoch 397 | loss: 0.3799 | Validation score: 0.5246 | Test score: 0.4940
# Epoch 398 | loss: 0.3812 | Validation score: 0.5335 | Test score: 0.4935
# Epoch 399 | loss: 0.3823 | Validation score: 0.5290 | Test score: 0.5040
# Epoch 400 | loss: 0.3764 | Validation score: 0.5278 | Test score: 0.4935
# Epoch 401 | loss: 0.3798 | Validation score: 0.5301 | Test score: 0.5060
# Epoch 402 | loss: 0.3775 | Validation score: 0.5239 | Test score: 0.5085
# Epoch 403 | loss: 0.3769 | Validation score: 0.5303 | Test score: 0.5004
# Epoch 404 | loss: 0.3808 | Validation score: 0.5223 | Test score: 0.5028
# Epoch 405 | loss: 0.3740 | Validation score: 0.5253 | Test score: 0.5081
# Epoch 406 | loss: 0.3740 | Validation score: 0.5235 | Test score: 0.5085
# Epoch 407 | loss: 0.3698 | Validation score: 0.5251 | Test score: 0.5097
# Epoch 408 | loss: 0.3756 | Validation score: 0.5246 | Test score: 0.5044
# Epoch 409 | loss: 0.3809 | Validation score: 0.5255 | Test score: 0.5121
# Epoch 410 | loss: 0.3718 | Validation score: 0.5264 | Test score: 0.4992
# Epoch 411 | loss: 0.3744 | Validation score: 0.5303 | Test score: 0.4976
# Epoch 412 | loss: 0.3803 | Validation score: 0.5271 | Test score: 0.5169
# Epoch 413 | loss: 0.3782 | Validation score: 0.5264 | Test score: 0.4903
# Epoch 414 | loss: 0.3776 | Validation score: 0.5255 | Test score: 0.5052
# Epoch 415 | loss: 0.3815 | Validation score: 0.5299 | Test score: 0.5004
# Epoch 416 | loss: 0.3716 | Validation score: 0.5319 | Test score: 0.4972
# Epoch 417 | loss: 0.3714 | Validation score: 0.5264 | Test score: 0.5000
# Epoch 418 | loss: 0.3766 | Validation score: 0.5258 | Test score: 0.5040
# Epoch 419 | loss: 0.3801 | Validation score: 0.5271 | Test score: 0.4996
# Epoch 420 | loss: 0.3761 | Validation score: 0.5321 | Test score: 0.5117
# Epoch 421 | loss: 0.3767 | Validation score: 0.5258 | Test score: 0.5105
# Epoch 422 | loss: 0.3744 | Validation score: 0.5253 | Test score: 0.5097
# Epoch 423 | loss: 0.3783 | Validation score: 0.5255 | Test score: 0.5077
# Epoch 424 | loss: 0.3753 | Validation score: 0.5223 | Test score: 0.5056
# Epoch 425 | loss: 0.3757 | Validation score: 0.5226 | Test score: 0.5073
# Epoch 426 | loss: 0.3738 | Validation score: 0.5249 | Test score: 0.5000
# Epoch 427 | loss: 0.3787 | Validation score: 0.5301 | Test score: 0.5024
# Epoch 428 | loss: 0.3787 | Validation score: 0.5237 | Test score: 0.5218
# Epoch 429 | loss: 0.3759 | Validation score: 0.5255 | Test score: 0.5101
# Epoch 430 | loss: 0.3730 | Validation score: 0.5214 | Test score: 0.5052
# Epoch 431 | loss: 0.3813 | Validation score: 0.5246 | Test score: 0.5016
# Epoch 432 | loss: 0.3711 | Validation score: 0.5269 | Test score: 0.5000
# Epoch 433 | loss: 0.3688 | Validation score: 0.5255 | Test score: 0.5024
# Epoch 434 | loss: 0.3707 | Validation score: 0.5258 | Test score: 0.4956
# Epoch 435 | loss: 0.3744 | Validation score: 0.5246 | Test score: 0.5012
# Epoch 436 | loss: 0.3731 | Validation score: 0.5269 | Test score: 0.4988
# Epoch 437 | loss: 0.3695 | Validation score: 0.5242 | Test score: 0.4964
# Epoch 438 | loss: 0.3737 | Validation score: 0.5287 | Test score: 0.5008
# Epoch 439 | loss: 0.3721 | Validation score: 0.5292 | Test score: 0.4964
# Epoch 440 | loss: 0.3780 | Validation score: 0.5217 | Test score: 0.4879
# Epoch 441 | loss: 0.3707 | Validation score: 0.5321 | Test score: 0.4976
# Epoch 442 | loss: 0.3731 | Validation score: 0.5278 | Test score: 0.5073
# Epoch 443 | loss: 0.3736 | Validation score: 0.5264 | Test score: 0.5141
# Epoch 444 | loss: 0.3695 | Validation score: 0.5283 | Test score: 0.4996
# Epoch 445 | loss: 0.3696 | Validation score: 0.5292 | Test score: 0.5016
# Epoch 446 | loss: 0.3708 | Validation score: 0.5242 | Test score: 0.5000
# Epoch 447 | loss: 0.3705 | Validation score: 0.5267 | Test score: 0.4992
# Epoch 448 | loss: 0.3729 | Validation score: 0.5228 | Test score: 0.4931
# Epoch 449 | loss: 0.3675 | Validation score: 0.5269 | Test score: 0.4996
# Epoch 450 | loss: 0.3749 | Validation score: 0.5280 | Test score: 0.4927
# Epoch 451 | loss: 0.3605 | Validation score: 0.5226 | Test score: 0.4984
# Epoch 452 | loss: 0.3662 | Validation score: 0.5233 | Test score: 0.5121
# Epoch 453 | loss: 0.3625 | Validation score: 0.5223 | Test score: 0.5020
# Epoch 454 | loss: 0.3659 | Validation score: 0.5294 | Test score: 0.4980
# Epoch 455 | loss: 0.3670 | Validation score: 0.5317 | Test score: 0.5048
# Epoch 456 | loss: 0.3675 | Validation score: 0.5262 | Test score: 0.5020
# Epoch 457 | loss: 0.3763 | Validation score: 0.5274 | Test score: 0.4964
# Epoch 458 | loss: 0.3651 | Validation score: 0.5278 | Test score: 0.5044
# Epoch 459 | loss: 0.3604 | Validation score: 0.5264 | Test score: 0.5097
# Epoch 460 | loss: 0.3685 | Validation score: 0.5251 | Test score: 0.4956
# Epoch 461 | loss: 0.3685 | Validation score: 0.5264 | Test score: 0.5069
# Epoch 462 | loss: 0.3672 | Validation score: 0.5160 | Test score: 0.5109
# Epoch 463 | loss: 0.3719 | Validation score: 0.5237 | Test score: 0.5048
# Epoch 464 | loss: 0.3672 | Validation score: 0.5290 | Test score: 0.5089
# Epoch 465 | loss: 0.3656 | Validation score: 0.5239 | Test score: 0.5024
# Epoch 466 | loss: 0.3629 | Validation score: 0.5203 | Test score: 0.4984
# Epoch 467 | loss: 0.3681 | Validation score: 0.5271 | Test score: 0.5012
# Epoch 468 | loss: 0.3666 | Validation score: 0.5230 | Test score: 0.5093
# Epoch 469 | loss: 0.3648 | Validation score: 0.5280 | Test score: 0.5073
# Epoch 470 | loss: 0.3660 | Validation score: 0.5228 | Test score: 0.5052
# Epoch 471 | loss: 0.3662 | Validation score: 0.5251 | Test score: 0.5000
# Epoch 472 | loss: 0.3691 | Validation score: 0.5239 | Test score: 0.5004
# Epoch 473 | loss: 0.3675 | Validation score: 0.5262 | Test score: 0.5056
# Epoch 474 | loss: 0.3612 | Validation score: 0.5235 | Test score: 0.5056
# Epoch 475 | loss: 0.3642 | Validation score: 0.5242 | Test score: 0.5040
# Epoch 476 | loss: 0.3612 | Validation score: 0.5180 | Test score: 0.4923
# Epoch 477 | loss: 0.3617 | Validation score: 0.5271 | Test score: 0.5004
# Epoch 478 | loss: 0.3709 | Validation score: 0.5253 | Test score: 0.4996
# Epoch 479 | loss: 0.3617 | Validation score: 0.5244 | Test score: 0.5004
# Epoch 480 | loss: 0.3579 | Validation score: 0.5233 | Test score: 0.4931
# Epoch 481 | loss: 0.3677 | Validation score: 0.5269 | Test score: 0.4883
# Epoch 482 | loss: 0.3649 | Validation score: 0.5262 | Test score: 0.4976
# Epoch 483 | loss: 0.3640 | Validation score: 0.5187 | Test score: 0.5028
# Epoch 484 | loss: 0.3663 | Validation score: 0.5201 | Test score: 0.5153
# Epoch 485 | loss: 0.3624 | Validation score: 0.5221 | Test score: 0.4976
# Epoch 486 | loss: 0.3629 | Validation score: 0.5242 | Test score: 0.4996
# Epoch 487 | loss: 0.3621 | Validation score: 0.5242 | Test score: 0.5089
# Epoch 488 | loss: 0.3605 | Validation score: 0.5223 | Test score: 0.5089
# Epoch 489 | loss: 0.3668 | Validation score: 0.5196 | Test score: 0.5089
# Epoch 490 | loss: 0.3599 | Validation score: 0.5274 | Test score: 0.5129
# Epoch 491 | loss: 0.3586 | Validation score: 0.5274 | Test score: 0.5185
# Epoch 492 | loss: 0.3576 | Validation score: 0.5217 | Test score: 0.5032
# Epoch 493 | loss: 0.3703 | Validation score: 0.5228 | Test score: 0.5040
# Epoch 494 | loss: 0.3622 | Validation score: 0.5264 | Test score: 0.5040
# Epoch 495 | loss: 0.3624 | Validation score: 0.5292 | Test score: 0.5016
# Epoch 496 | loss: 0.3679 | Validation score: 0.5255 | Test score: 0.4944
# Epoch 497 | loss: 0.3618 | Validation score: 0.5251 | Test score: 0.5065
# Epoch 498 | loss: 0.3601 | Validation score: 0.5269 | Test score: 0.4980
# Epoch 499 | loss: 0.3597 | Validation score: 0.5198 | Test score: 0.5040
# Epoch 500 | loss: 0.3663 | Validation score: 0.5185 | Test score: 0.4923
# Epoch 501 | loss: 0.3626 | Validation score: 0.5223 | Test score: 0.5036
# Epoch 502 | loss: 0.3642 | Validation score: 0.5255 | Test score: 0.5024
# Epoch 503 | loss: 0.3642 | Validation score: 0.5269 | Test score: 0.5028
# Epoch 504 | loss: 0.3652 | Validation score: 0.5237 | Test score: 0.5097
# Epoch 505 | loss: 0.3604 | Validation score: 0.5283 | Test score: 0.4976
# Epoch 506 | loss: 0.3577 | Validation score: 0.5239 | Test score: 0.5044
# Epoch 507 | loss: 0.3581 | Validation score: 0.5198 | Test score: 0.5016
# Epoch 508 | loss: 0.3587 | Validation score: 0.5255 | Test score: 0.5060
# Epoch 509 | loss: 0.3587 | Validation score: 0.5219 | Test score: 0.4931
# Epoch 510 | loss: 0.3556 | Validation score: 0.5207 | Test score: 0.5008
# Epoch 511 | loss: 0.3586 | Validation score: 0.5258 | Test score: 0.5032
# Epoch 512 | loss: 0.3689 | Validation score: 0.5258 | Test score: 0.4968
# Epoch 513 | loss: 0.3572 | Validation score: 0.5173 | Test score: 0.5081
# Epoch 514 | loss: 0.3609 | Validation score: 0.5242 | Test score: 0.5177
# Epoch 515 | loss: 0.3614 | Validation score: 0.5260 | Test score: 0.5060
# Epoch 516 | loss: 0.3540 | Validation score: 0.5233 | Test score: 0.5052
# Epoch 517 | loss: 0.3629 | Validation score: 0.5237 | Test score: 0.5141
# Epoch 518 | loss: 0.3605 | Validation score: 0.5278 | Test score: 0.5185
# Epoch 519 | loss: 0.3569 | Validation score: 0.5242 | Test score: 0.5052
# Epoch 520 | loss: 0.3694 | Validation score: 0.5262 | Test score: 0.5125
# Epoch 521 | loss: 0.3571 | Validation score: 0.5219 | Test score: 0.5089
# Epoch 522 | loss: 0.3607 | Validation score: 0.5251 | Test score: 0.5032
# Epoch 523 | loss: 0.3559 | Validation score: 0.5246 | Test score: 0.5089
# Epoch 524 | loss: 0.3614 | Validation score: 0.5306 | Test score: 0.5081
# Epoch 525 | loss: 0.3551 | Validation score: 0.5269 | Test score: 0.5032
# Epoch 526 | loss: 0.3517 | Validation score: 0.5267 | Test score: 0.5024
# Epoch 527 | loss: 0.3557 | Validation score: 0.5237 | Test score: 0.5032
# Epoch 528 | loss: 0.3618 | Validation score: 0.5280 | Test score: 0.4960
# Epoch 529 | loss: 0.3594 | Validation score: 0.5237 | Test score: 0.5040
# Epoch 530 | loss: 0.3605 | Validation score: 0.5185 | Test score: 0.4960
# Epoch 531 | loss: 0.3580 | Validation score: 0.5189 | Test score: 0.4883
# Epoch 532 | loss: 0.3586 | Validation score: 0.5301 | Test score: 0.5028
# Epoch 533 | loss: 0.3558 | Validation score: 0.5249 | Test score: 0.4887
# Epoch 534 | loss: 0.3550 | Validation score: 0.5246 | Test score: 0.5060
# Epoch 535 | loss: 0.3554 | Validation score: 0.5244 | Test score: 0.4968
# Epoch 536 | loss: 0.3581 | Validation score: 0.5214 | Test score: 0.5085
# Epoch 537 | loss: 0.3581 | Validation score: 0.5274 | Test score: 0.4968
# Epoch 538 | loss: 0.3572 | Validation score: 0.5228 | Test score: 0.5044
# Epoch 539 | loss: 0.3566 | Validation score: 0.5249 | Test score: 0.5004
# Epoch 540 | loss: 0.3552 | Validation score: 0.5278 | Test score: 0.5012
# Epoch 541 | loss: 0.3577 | Validation score: 0.5267 | Test score: 0.5060
# Epoch 542 | loss: 0.3570 | Validation score: 0.5176 | Test score: 0.5089
# Epoch 543 | loss: 0.3545 | Validation score: 0.5207 | Test score: 0.4923
# Epoch 544 | loss: 0.3561 | Validation score: 0.5192 | Test score: 0.5044
# Epoch 545 | loss: 0.3552 | Validation score: 0.5251 | Test score: 0.4972
# Epoch 546 | loss: 0.3560 | Validation score: 0.5228 | Test score: 0.5060
# Epoch 547 | loss: 0.3584 | Validation score: 0.5187 | Test score: 0.5060
# Epoch 548 | loss: 0.3482 | Validation score: 0.5274 | Test score: 0.5077
# Epoch 549 | loss: 0.3579 | Validation score: 0.5251 | Test score: 0.5044
# Epoch 550 | loss: 0.3551 | Validation score: 0.5194 | Test score: 0.5008
# Epoch 551 | loss: 0.3567 | Validation score: 0.5233 | Test score: 0.4952
# Epoch 552 | loss: 0.3552 | Validation score: 0.5237 | Test score: 0.5040
# Epoch 553 | loss: 0.3652 | Validation score: 0.5207 | Test score: 0.4984
# Epoch 554 | loss: 0.3583 | Validation score: 0.5239 | Test score: 0.4988
# Epoch 555 | loss: 0.3559 | Validation score: 0.5226 | Test score: 0.5056
# Epoch 556 | loss: 0.3531 | Validation score: 0.5203 | Test score: 0.5065
# Epoch 557 | loss: 0.3545 | Validation score: 0.5226 | Test score: 0.4972
# Epoch 558 | loss: 0.3547 | Validation score: 0.5249 | Test score: 0.5036
# Epoch 559 | loss: 0.3474 | Validation score: 0.5246 | Test score: 0.5000
# Epoch 560 | loss: 0.3538 | Validation score: 0.5192 | Test score: 0.4968
# Epoch 561 | loss: 0.3537 | Validation score: 0.5239 | Test score: 0.5065
# Epoch 562 | loss: 0.3519 | Validation score: 0.5207 | Test score: 0.4972
# Epoch 563 | loss: 0.3551 | Validation score: 0.5233 | Test score: 0.5065
# Epoch 564 | loss: 0.3590 | Validation score: 0.5262 | Test score: 0.4960
# Epoch 565 | loss: 0.3471 | Validation score: 0.5219 | Test score: 0.4952
# Epoch 566 | loss: 0.3567 | Validation score: 0.5221 | Test score: 0.5052
# Epoch 567 | loss: 0.3447 | Validation score: 0.5189 | Test score: 0.5141
# Epoch 568 | loss: 0.3526 | Validation score: 0.5219 | Test score: 0.5065
# Epoch 569 | loss: 0.3525 | Validation score: 0.5223 | Test score: 0.5077
# Epoch 570 | loss: 0.3518 | Validation score: 0.5194 | Test score: 0.5048
# Epoch 571 | loss: 0.3592 | Validation score: 0.5237 | Test score: 0.5044
# Epoch 572 | loss: 0.3587 | Validation score: 0.5260 | Test score: 0.5081
# Epoch 573 | loss: 0.3546 | Validation score: 0.5226 | Test score: 0.5008
# Epoch 574 | loss: 0.3577 | Validation score: 0.5274 | Test score: 0.4952
# Epoch 575 | loss: 0.3522 | Validation score: 0.5306 | Test score: 0.5052
# Epoch 576 | loss: 0.3484 | Validation score: 0.5217 | Test score: 0.5081
# Epoch 577 | loss: 0.3539 | Validation score: 0.5324 | Test score: 0.4984
# Epoch 578 | loss: 0.3542 | Validation score: 0.5249 | Test score: 0.5069
# Epoch 579 | loss: 0.3538 | Validation score: 0.5196 | Test score: 0.5020
# Epoch 580 | loss: 0.3556 | Validation score: 0.5217 | Test score: 0.5000
# Epoch 581 | loss: 0.3542 | Validation score: 0.5187 | Test score: 0.4960
# Epoch 582 | loss: 0.3580 | Validation score: 0.5201 | Test score: 0.5028
# Epoch 583 | loss: 0.3566 | Validation score: 0.5205 | Test score: 0.5020
# Epoch 584 | loss: 0.3494 | Validation score: 0.5205 | Test score: 0.4923
# Epoch 585 | loss: 0.3555 | Validation score: 0.5144 | Test score: 0.5044
# Epoch 586 | loss: 0.3480 | Validation score: 0.5171 | Test score: 0.5032
# Epoch 587 | loss: 0.3512 | Validation score: 0.5233 | Test score: 0.5060
# Epoch 588 | loss: 0.3518 | Validation score: 0.5205 | Test score: 0.4996
# Epoch 589 | loss: 0.3530 | Validation score: 0.5226 | Test score: 0.5052
# Epoch 590 | loss: 0.3521 | Validation score: 0.5258 | Test score: 0.5036
# Epoch 591 | loss: 0.3575 | Validation score: 0.5230 | Test score: 0.5129
# Epoch 592 | loss: 0.3522 | Validation score: 0.5196 | Test score: 0.5004
# Epoch 593 | loss: 0.3522 | Validation score: 0.5258 | Test score: 0.5060
# Epoch 594 | loss: 0.3494 | Validation score: 0.5269 | Test score: 0.5028
# Epoch 595 | loss: 0.3500 | Validation score: 0.5260 | Test score: 0.5008
# Epoch 596 | loss: 0.3421 | Validation score: 0.5278 | Test score: 0.5060
# Epoch 597 | loss: 0.3464 | Validation score: 0.5264 | Test score: 0.4992
# Epoch 598 | loss: 0.3485 | Validation score: 0.5253 | Test score: 0.5040
# Epoch 599 | loss: 0.3500 | Validation score: 0.5221 | Test score: 0.4968
# Epoch 600 | loss: 0.3504 | Validation score: 0.5226 | Test score: 0.5028
# Epoch 601 | loss: 0.3493 | Validation score: 0.5205 | Test score: 0.5065
# Epoch 602 | loss: 0.3503 | Validation score: 0.5217 | Test score: 0.5028
# Epoch 603 | loss: 0.3571 | Validation score: 0.5230 | Test score: 0.5133
# Epoch 604 | loss: 0.3534 | Validation score: 0.5267 | Test score: 0.5153
# Epoch 605 | loss: 0.3411 | Validation score: 0.5207 | Test score: 0.5121
# Epoch 606 | loss: 0.3455 | Validation score: 0.5242 | Test score: 0.5121
# Epoch 607 | loss: 0.3488 | Validation score: 0.5205 | Test score: 0.5218
# Epoch 608 | loss: 0.3430 | Validation score: 0.5233 | Test score: 0.5073
# Epoch 609 | loss: 0.3514 | Validation score: 0.5223 | Test score: 0.5016
# Epoch 610 | loss: 0.3485 | Validation score: 0.5192 | Test score: 0.5081
# Epoch 611 | loss: 0.3525 | Validation score: 0.5228 | Test score: 0.5101
# Epoch 612 | loss: 0.3481 | Validation score: 0.5223 | Test score: 0.5113
# Epoch 613 | loss: 0.3467 | Validation score: 0.5226 | Test score: 0.5004
# Epoch 614 | loss: 0.3540 | Validation score: 0.5255 | Test score: 0.5024
# Epoch 615 | loss: 0.3478 | Validation score: 0.5274 | Test score: 0.5089
# Epoch 616 | loss: 0.3470 | Validation score: 0.5228 | Test score: 0.5040
# Epoch 617 | loss: 0.3508 | Validation score: 0.5269 | Test score: 0.5012
# Epoch 618 | loss: 0.3502 | Validation score: 0.5264 | Test score: 0.5133
# Epoch 619 | loss: 0.3463 | Validation score: 0.5285 | Test score: 0.5117
# Epoch 620 | loss: 0.3504 | Validation score: 0.5212 | Test score: 0.5117
# Epoch 621 | loss: 0.3477 | Validation score: 0.5280 | Test score: 0.5065
# Epoch 622 | loss: 0.3459 | Validation score: 0.5201 | Test score: 0.5044
# Epoch 623 | loss: 0.3444 | Validation score: 0.5214 | Test score: 0.5069
# Epoch 624 | loss: 0.3431 | Validation score: 0.5189 | Test score: 0.4956
# Epoch 625 | loss: 0.3390 | Validation score: 0.5176 | Test score: 0.5077
# Epoch 626 | loss: 0.3458 | Validation score: 0.5194 | Test score: 0.5060
# Epoch 627 | loss: 0.3391 | Validation score: 0.5223 | Test score: 0.5073
# Epoch 628 | loss: 0.3430 | Validation score: 0.5150 | Test score: 0.5097
# Epoch 629 | loss: 0.3494 | Validation score: 0.5198 | Test score: 0.5093
# Epoch 630 | loss: 0.3452 | Validation score: 0.5198 | Test score: 0.5113
# Epoch 631 | loss: 0.3431 | Validation score: 0.5196 | Test score: 0.5097
# Epoch 632 | loss: 0.3431 | Validation score: 0.5192 | Test score: 0.5016
# Epoch 633 | loss: 0.3411 | Validation score: 0.5214 | Test score: 0.5121
# Epoch 634 | loss: 0.3422 | Validation score: 0.5203 | Test score: 0.4980
# Epoch 635 | loss: 0.3397 | Validation score: 0.5283 | Test score: 0.5020
# Epoch 636 | loss: 0.3467 | Validation score: 0.5201 | Test score: 0.5004
# Epoch 637 | loss: 0.3455 | Validation score: 0.5262 | Test score: 0.5048
# Epoch 638 | loss: 0.3469 | Validation score: 0.5239 | Test score: 0.5165
# Epoch 639 | loss: 0.3497 | Validation score: 0.5223 | Test score: 0.5234
# Epoch 640 | loss: 0.3473 | Validation score: 0.5219 | Test score: 0.5105
# Epoch 641 | loss: 0.3414 | Validation score: 0.5301 | Test score: 0.5145
# Epoch 642 | loss: 0.3466 | Validation score: 0.5264 | Test score: 0.5173
# Epoch 643 | loss: 0.3355 | Validation score: 0.5278 | Test score: 0.5032
# Epoch 644 | loss: 0.3443 | Validation score: 0.5283 | Test score: 0.5113
# Epoch 645 | loss: 0.3420 | Validation score: 0.5219 | Test score: 0.4992
# Epoch 646 | loss: 0.3491 | Validation score: 0.5237 | Test score: 0.4980
# Epoch 647 | loss: 0.3439 | Validation score: 0.5242 | Test score: 0.5085
# Epoch 648 | loss: 0.3487 | Validation score: 0.5280 | Test score: 0.5065
# Epoch 649 | loss: 0.3420 | Validation score: 0.5235 | Test score: 0.5069
# Epoch 650 | loss: 0.3507 | Validation score: 0.5292 | Test score: 0.4972
# Epoch 651 | loss: 0.3408 | Validation score: 0.5219 | Test score: 0.5056
# Epoch 652 | loss: 0.3478 | Validation score: 0.5285 | Test score: 0.5109
# Epoch 653 | loss: 0.3428 | Validation score: 0.5294 | Test score: 0.4923
# Epoch 654 | loss: 0.3481 | Validation score: 0.5235 | Test score: 0.5020
# Epoch 655 | loss: 0.3441 | Validation score: 0.5217 | Test score: 0.5004
# Epoch 656 | loss: 0.3402 | Validation score: 0.5221 | Test score: 0.5081
# Epoch 657 | loss: 0.3419 | Validation score: 0.5223 | Test score: 0.4976
# ...
# Epoch 1785 | loss: 0.2895 | Validation score: 0.5244 | Test score: 0.5065
# Epoch 1786 | loss: 0.2806 | Validation score: 0.5260 | Test score: 0.5008
# Epoch 1787 | loss: 0.2843 | Validation score: 0.5267 | Test score: 0.5048
# Epoch 1788 | loss: 0.2900 | Validation score: 0.5258 | Test score: 0.4984
# Epoch 1789 | loss: 0.2856 | Validation score: 0.5315 | Test score: 0.4988
# Epoch 1790 | loss: 0.2904 | Validation score: 0.5280 | Test score: 0.5060
# Epoch 1791 | loss: 0.2893 | Validation score: 0.5301 | Test score: 0.5008
# Epoch 1792 | loss: 0.2880 | Validation score: 0.5271 | Test score: 0.5000
# Epoch 1793 | loss: 0.2859 | Validation score: 0.5283 | Test score: 0.5004
# Epoch 1794 | loss: 0.2879 | Validation score: 0.5312 | Test score: 0.5060
# Epoch 1795 | loss: 0.2852 | Validation score: 0.5292 | Test score: 0.5129
# Epoch 1796 | loss: 0.2815 | Validation score: 0.5308 | Test score: 0.5040
# Epoch 1797 | loss: 0.2878 | Validation score: 0.5274 | Test score: 0.5073
# Epoch 1798 | loss: 0.2830 | Validation score: 0.5274 | Test score: 0.5141
# Epoch 1799 | loss: 0.2884 | Validation score: 0.5337 | Test score: 0.5105
# Epoch 1800 | loss: 0.2938 | Validation score: 0.5319 | Test score: 0.5024
# Epoch 1801 | loss: 0.2931 | Validation score: 0.5271 | Test score: 0.5113
# Epoch 1802 | loss: 0.2876 | Validation score: 0.5269 | Test score: 0.5093
# Epoch 1803 | loss: 0.2900 | Validation score: 0.5285 | Test score: 0.5065
# Epoch 1804 | loss: 0.2870 | Validation score: 0.5303 | Test score: 0.5081
# Epoch 1805 | loss: 0.2851 | Validation score: 0.5299 | Test score: 0.5036
# Epoch 1806 | loss: 0.2887 | Validation score: 0.5321 | Test score: 0.5052
# Epoch 1807 | loss: 0.2853 | Validation score: 0.5315 | Test score: 0.5085
# Epoch 1808 | loss: 0.2883 | Validation score: 0.5299 | Test score: 0.5065
# Epoch 1809 | loss: 0.2890 | Validation score: 0.5331 | Test score: 0.5040
# Epoch 1810 | loss: 0.2878 | Validation score: 0.5301 | Test score: 0.5052
# Epoch 1811 | loss: 0.2784 | Validation score: 0.5292 | Test score: 0.5081
# Epoch 1812 | loss: 0.2852 | Validation score: 0.5306 | Test score: 0.4976
# Epoch 1813 | loss: 0.2857 | Validation score: 0.5333 | Test score: 0.5036
# Epoch 1814 | loss: 0.2825 | Validation score: 0.5292 | Test score: 0.5093
# Epoch 1815 | loss: 0.2918 | Validation score: 0.5328 | Test score: 0.5085
# Epoch 1816 | loss: 0.2886 | Validation score: 0.5312 | Test score: 0.5153
# Epoch 1817 | loss: 0.2831 | Validation score: 0.5315 | Test score: 0.5052
# Epoch 1818 | loss: 0.2902 | Validation score: 0.5303 | Test score: 0.5065
# Epoch 1819 | loss: 0.2949 | Validation score: 0.5290 | Test score: 0.5052
# Epoch 1820 | loss: 0.2892 | Validation score: 0.5242 | Test score: 0.5052
# Epoch 1821 | loss: 0.2845 | Validation score: 0.5269 | Test score: 0.5028
# Epoch 1822 | loss: 0.2930 | Validation score: 0.5296 | Test score: 0.4960
# Epoch 1823 | loss: 0.2903 | Validation score: 0.5217 | Test score: 0.5145
# Epoch 1824 | loss: 0.2812 | Validation score: 0.5292 | Test score: 0.4992
# Epoch 1825 | loss: 0.2863 | Validation score: 0.5306 | Test score: 0.5052
# Epoch 1826 | loss: 0.2845 | Validation score: 0.5340 | Test score: 0.5125
# Epoch 1827 | loss: 0.2797 | Validation score: 0.5258 | Test score: 0.5133
# Epoch 1828 | loss: 0.2876 | Validation score: 0.5253 | Test score: 0.5105
# Epoch 1829 | loss: 0.2902 | Validation score: 0.5317 | Test score: 0.5109
# Epoch 1830 | loss: 0.2831 | Validation score: 0.5285 | Test score: 0.5044
# Epoch 1831 | loss: 0.2883 | Validation score: 0.5299 | Test score: 0.5101
# Epoch 1832 | loss: 0.2887 | Validation score: 0.5324 | Test score: 0.5069
# Epoch 1833 | loss: 0.2853 | Validation score: 0.5324 | Test score: 0.5044
# Epoch 1834 | loss: 0.2915 | Validation score: 0.5301 | Test score: 0.5109
# Epoch 1835 | loss: 0.2940 | Validation score: 0.5269 | Test score: 0.5101
# Epoch 1836 | loss: 0.2854 | Validation score: 0.5292 | Test score: 0.5056
# Epoch 1837 | loss: 0.2893 | Validation score: 0.5287 | Test score: 0.5073
# Epoch 1838 | loss: 0.2873 | Validation score: 0.5317 | Test score: 0.5121
# Epoch 1839 | loss: 0.2886 | Validation score: 0.5306 | Test score: 0.5109
# Epoch 1840 | loss: 0.2911 | Validation score: 0.5315 | Test score: 0.5081
# Epoch 1841 | loss: 0.2932 | Validation score: 0.5310 | Test score: 0.5052
# Epoch 1842 | loss: 0.2812 | Validation score: 0.5290 | Test score: 0.5024
# Epoch 1843 | loss: 0.2777 | Validation score: 0.5285 | Test score: 0.5125
# Epoch 1844 | loss: 0.2805 | Validation score: 0.5312 | Test score: 0.4984
# Epoch 1845 | loss: 0.2874 | Validation score: 0.5333 | Test score: 0.5089
# Epoch 1846 | loss: 0.2917 | Validation score: 0.5274 | Test score: 0.5153
# Epoch 1847 | loss: 0.2824 | Validation score: 0.5283 | Test score: 0.5181
# Epoch 1848 | loss: 0.2927 | Validation score: 0.5312 | Test score: 0.5020
# Epoch 1849 | loss: 0.2837 | Validation score: 0.5294 | Test score: 0.5060
# Epoch 1850 | loss: 0.2871 | Validation score: 0.5328 | Test score: 0.5137
# Epoch 1851 | loss: 0.2869 | Validation score: 0.5315 | Test score: 0.5073
# Epoch 1852 | loss: 0.2828 | Validation score: 0.5285 | Test score: 0.5060
# Epoch 1853 | loss: 0.2842 | Validation score: 0.5258 | Test score: 0.5028
# Epoch 1854 | loss: 0.2888 | Validation score: 0.5271 | Test score: 0.5117
# Epoch 1855 | loss: 0.2874 | Validation score: 0.5260 | Test score: 0.5141
# Epoch 1856 | loss: 0.2835 | Validation score: 0.5312 | Test score: 0.5181
# Epoch 1857 | loss: 0.2870 | Validation score: 0.5271 | Test score: 0.5153
# Epoch 1858 | loss: 0.2852 | Validation score: 0.5276 | Test score: 0.5141
# Epoch 1859 | loss: 0.2884 | Validation score: 0.5308 | Test score: 0.5161
# Epoch 1860 | loss: 0.2817 | Validation score: 0.5278 | Test score: 0.5065
# Epoch 1861 | loss: 0.2858 | Validation score: 0.5271 | Test score: 0.5093
# Epoch 1862 | loss: 0.2833 | Validation score: 0.5283 | Test score: 0.5137
# Epoch 1863 | loss: 0.2822 | Validation score: 0.5294 | Test score: 0.5069
# Epoch 1864 | loss: 0.2868 | Validation score: 0.5239 | Test score: 0.5081
# Epoch 1865 | loss: 0.2864 | Validation score: 0.5287 | Test score: 0.5129
# Epoch 1866 | loss: 0.2843 | Validation score: 0.5253 | Test score: 0.5048
# Epoch 1867 | loss: 0.2883 | Validation score: 0.5299 | Test score: 0.5060
# Epoch 1868 | loss: 0.2868 | Validation score: 0.5321 | Test score: 0.5032
# Epoch 1869 | loss: 0.2826 | Validation score: 0.5308 | Test score: 0.4968
# Epoch 1870 | loss: 0.2848 | Validation score: 0.5315 | Test score: 0.5048
# Epoch 1871 | loss: 0.2785 | Validation score: 0.5292 | Test score: 0.5125
# Epoch 1872 | loss: 0.2858 | Validation score: 0.5335 | Test score: 0.5069
# Epoch 1873 | loss: 0.2906 | Validation score: 0.5333 | Test score: 0.5105
# Epoch 1874 | loss: 0.2864 | Validation score: 0.5363 | Test score: 0.5133
# Epoch 1875 | loss: 0.2838 | Validation score: 0.5283 | Test score: 0.5040
# Epoch 1876 | loss: 0.2877 | Validation score: 0.5287 | Test score: 0.5093
# Epoch 1877 | loss: 0.2871 | Validation score: 0.5276 | Test score: 0.5101
# Epoch 1878 | loss: 0.2859 | Validation score: 0.5303 | Test score: 0.5117
# Epoch 1879 | loss: 0.2830 | Validation score: 0.5326 | Test score: 0.5077
# Epoch 1880 | loss: 0.2838 | Validation score: 0.5246 | Test score: 0.5149
# Epoch 1881 | loss: 0.2865 | Validation score: 0.5296 | Test score: 0.5198
# Epoch 1882 | loss: 0.2883 | Validation score: 0.5251 | Test score: 0.5105
# Epoch 1883 | loss: 0.2813 | Validation score: 0.5303 | Test score: 0.5181
# Epoch 1884 | loss: 0.2895 | Validation score: 0.5290 | Test score: 0.5185
# Epoch 1885 | loss: 0.2819 | Validation score: 0.5214 | Test score: 0.5194
# Epoch 1886 | loss: 0.2858 | Validation score: 0.5271 | Test score: 0.5109
# Epoch 1887 | loss: 0.2935 | Validation score: 0.5306 | Test score: 0.5145
# Epoch 1888 | loss: 0.2847 | Validation score: 0.5287 | Test score: 0.4984
# Epoch 1889 | loss: 0.2845 | Validation score: 0.5296 | Test score: 0.5016
# Epoch 1890 | loss: 0.2865 | Validation score: 0.5280 | Test score: 0.5065
# Epoch 1891 | loss: 0.2911 | Validation score: 0.5312 | Test score: 0.5097
# Epoch 1892 | loss: 0.2838 | Validation score: 0.5306 | Test score: 0.5044
# Epoch 1893 | loss: 0.2893 | Validation score: 0.5292 | Test score: 0.5056
# Epoch 1894 | loss: 0.2888 | Validation score: 0.5287 | Test score: 0.5028
# Epoch 1895 | loss: 0.2816 | Validation score: 0.5276 | Test score: 0.5044
# Epoch 1896 | loss: 0.2831 | Validation score: 0.5292 | Test score: 0.5024
# Epoch 1897 | loss: 0.2880 | Validation score: 0.5251 | Test score: 0.5089
# Epoch 1898 | loss: 0.2845 | Validation score: 0.5285 | Test score: 0.5040
# Epoch 1899 | loss: 0.2817 | Validation score: 0.5292 | Test score: 0.5040
# Epoch 1900 | loss: 0.2805 | Validation score: 0.5337 | Test score: 0.5125
# Epoch 1901 | loss: 0.2795 | Validation score: 0.5317 | Test score: 0.4996
# Epoch 1902 | loss: 0.2917 | Validation score: 0.5267 | Test score: 0.5004
# Epoch 1903 | loss: 0.2794 | Validation score: 0.5303 | Test score: 0.5125
# Epoch 1904 | loss: 0.2922 | Validation score: 0.5269 | Test score: 0.5016
# Epoch 1905 | loss: 0.2844 | Validation score: 0.5258 | Test score: 0.5133
# Epoch 1906 | loss: 0.2881 | Validation score: 0.5292 | Test score: 0.5109
# Epoch 1907 | loss: 0.2847 | Validation score: 0.5260 | Test score: 0.5121
# Epoch 1908 | loss: 0.2826 | Validation score: 0.5264 | Test score: 0.5153
# Epoch 1909 | loss: 0.2826 | Validation score: 0.5230 | Test score: 0.5141
# Epoch 1910 | loss: 0.2863 | Validation score: 0.5239 | Test score: 0.5097
# Epoch 1911 | loss: 0.2855 | Validation score: 0.5251 | Test score: 0.5081
# Epoch 1912 | loss: 0.2805 | Validation score: 0.5274 | Test score: 0.5101
# Epoch 1913 | loss: 0.2904 | Validation score: 0.5303 | Test score: 0.5069
# Epoch 1914 | loss: 0.2908 | Validation score: 0.5292 | Test score: 0.5117
# Epoch 1915 | loss: 0.2805 | Validation score: 0.5255 | Test score: 0.5065
# Epoch 1916 | loss: 0.2901 | Validation score: 0.5317 | Test score: 0.5048
# Epoch 1917 | loss: 0.2893 | Validation score: 0.5331 | Test score: 0.5101
# Epoch 1918 | loss: 0.2819 | Validation score: 0.5276 | Test score: 0.5040
# Epoch 1919 | loss: 0.2831 | Validation score: 0.5246 | Test score: 0.5028
# Epoch 1920 | loss: 0.2867 | Validation score: 0.5317 | Test score: 0.5081
# Epoch 1921 | loss: 0.2862 | Validation score: 0.5274 | Test score: 0.5048
# Epoch 1922 | loss: 0.2833 | Validation score: 0.5296 | Test score: 0.5008
# Epoch 1923 | loss: 0.2877 | Validation score: 0.5267 | Test score: 0.5145
# Epoch 1924 | loss: 0.2880 | Validation score: 0.5280 | Test score: 0.5157
# Epoch 1925 | loss: 0.2862 | Validation score: 0.5296 | Test score: 0.5145
# Epoch 1926 | loss: 0.2807 | Validation score: 0.5267 | Test score: 0.5052
# Epoch 1927 | loss: 0.2791 | Validation score: 0.5299 | Test score: 0.5048
# Epoch 1928 | loss: 0.2875 | Validation score: 0.5306 | Test score: 0.5125
# Epoch 1929 | loss: 0.2783 | Validation score: 0.5283 | Test score: 0.5121
# Epoch 1930 | loss: 0.2883 | Validation score: 0.5342 | Test score: 0.5117
# Epoch 1931 | loss: 0.2799 | Validation score: 0.5315 | Test score: 0.5121
# Epoch 1932 | loss: 0.2820 | Validation score: 0.5271 | Test score: 0.5105
# Epoch 1933 | loss: 0.2797 | Validation score: 0.5285 | Test score: 0.5129
# Epoch 1934 | loss: 0.2796 | Validation score: 0.5351 | Test score: 0.5077
# Epoch 1935 | loss: 0.2835 | Validation score: 0.5328 | Test score: 0.5065
# Epoch 1936 | loss: 0.2901 | Validation score: 0.5303 | Test score: 0.5073
# Epoch 1937 | loss: 0.2805 | Validation score: 0.5324 | Test score: 0.5105
# Epoch 1938 | loss: 0.2834 | Validation score: 0.5324 | Test score: 0.4996
# Epoch 1939 | loss: 0.2858 | Validation score: 0.5290 | Test score: 0.5032
# Epoch 1940 | loss: 0.2860 | Validation score: 0.5308 | Test score: 0.4992
# Epoch 1941 | loss: 0.2799 | Validation score: 0.5255 | Test score: 0.5081
# Epoch 1942 | loss: 0.2851 | Validation score: 0.5253 | Test score: 0.5093
# Epoch 1943 | loss: 0.2835 | Validation score: 0.5290 | Test score: 0.4996
# Epoch 1944 | loss: 0.2841 | Validation score: 0.5283 | Test score: 0.4992
# Epoch 1945 | loss: 0.2839 | Validation score: 0.5264 | Test score: 0.5097
# Epoch 1946 | loss: 0.2861 | Validation score: 0.5276 | Test score: 0.5000
# Epoch 1947 | loss: 0.2784 | Validation score: 0.5280 | Test score: 0.5077
# Epoch 1948 | loss: 0.2807 | Validation score: 0.5276 | Test score: 0.5008
# Epoch 1949 | loss: 0.2843 | Validation score: 0.5271 | Test score: 0.5117
# Epoch 1950 | loss: 0.2836 | Validation score: 0.5251 | Test score: 0.5109
# Epoch 1951 | loss: 0.2853 | Validation score: 0.5310 | Test score: 0.5060
# Epoch 1952 | loss: 0.2834 | Validation score: 0.5276 | Test score: 0.5085
# Epoch 1953 | loss: 0.2814 | Validation score: 0.5242 | Test score: 0.5117
# Epoch 1954 | loss: 0.2855 | Validation score: 0.5317 | Test score: 0.5206
# Epoch 1955 | loss: 0.2795 | Validation score: 0.5285 | Test score: 0.5121
# Epoch 1956 | loss: 0.2810 | Validation score: 0.5317 | Test score: 0.5085
# Epoch 1957 | loss: 0.2814 | Validation score: 0.5278 | Test score: 0.5198
# Epoch 1958 | loss: 0.2794 | Validation score: 0.5228 | Test score: 0.5089
# Epoch 1959 | loss: 0.2811 | Validation score: 0.5249 | Test score: 0.5093
# Epoch 1960 | loss: 0.2844 | Validation score: 0.5251 | Test score: 0.5226
# Epoch 1961 | loss: 0.2821 | Validation score: 0.5258 | Test score: 0.5173
# Epoch 1962 | loss: 0.2780 | Validation score: 0.5271 | Test score: 0.5133
# Epoch 1963 | loss: 0.2795 | Validation score: 0.5262 | Test score: 0.5036
# Epoch 1964 | loss: 0.2833 | Validation score: 0.5260 | Test score: 0.5040
# Epoch 1965 | loss: 0.2856 | Validation score: 0.5264 | Test score: 0.5004
# Epoch 1966 | loss: 0.2797 | Validation score: 0.5260 | Test score: 0.5073
# Epoch 1967 | loss: 0.2841 | Validation score: 0.5306 | Test score: 0.5093
# Epoch 1968 | loss: 0.2838 | Validation score: 0.5306 | Test score: 0.5137
# Epoch 1969 | loss: 0.2856 | Validation score: 0.5228 | Test score: 0.5129
# Epoch 1970 | loss: 0.2869 | Validation score: 0.5278 | Test score: 0.5089
# Epoch 1971 | loss: 0.2891 | Validation score: 0.5249 | Test score: 0.5004
# Epoch 1972 | loss: 0.2832 | Validation score: 0.5242 | Test score: 0.5097
# Epoch 1973 | loss: 0.2817 | Validation score: 0.5269 | Test score: 0.5024
# Epoch 1974 | loss: 0.2856 | Validation score: 0.5274 | Test score: 0.5032
# Epoch 1975 | loss: 0.2836 | Validation score: 0.5258 | Test score: 0.5024
# Epoch 1976 | loss: 0.2825 | Validation score: 0.5292 | Test score: 0.5052
# Epoch 1977 | loss: 0.2864 | Validation score: 0.5258 | Test score: 0.5056
# Epoch 1978 | loss: 0.2832 | Validation score: 0.5299 | Test score: 0.5137
# Epoch 1979 | loss: 0.2790 | Validation score: 0.5249 | Test score: 0.5048
# Epoch 1980 | loss: 0.2863 | Validation score: 0.5290 | Test score: 0.5129
# Epoch 1981 | loss: 0.2827 | Validation score: 0.5264 | Test score: 0.5125
# Epoch 1982 | loss: 0.2795 | Validation score: 0.5249 | Test score: 0.5181
# Epoch 1983 | loss: 0.2768 | Validation score: 0.5292 | Test score: 0.5101
# Epoch 1984 | loss: 0.2834 | Validation score: 0.5274 | Test score: 0.5040
# Epoch 1985 | loss: 0.2797 | Validation score: 0.5287 | Test score: 0.5097
# Epoch 1986 | loss: 0.2871 | Validation score: 0.5253 | Test score: 0.5032
# Epoch 1987 | loss: 0.2803 | Validation score: 0.5296 | Test score: 0.5093
# Epoch 1988 | loss: 0.2890 | Validation score: 0.5283 | Test score: 0.5008
# Epoch 1989 | loss: 0.2800 | Validation score: 0.5317 | Test score: 0.5000
# Epoch 1990 | loss: 0.2791 | Validation score: 0.5308 | Test score: 0.5109
# Epoch 1991 | loss: 0.2855 | Validation score: 0.5276 | Test score: 0.5145
# Epoch 1992 | loss: 0.2854 | Validation score: 0.5315 | Test score: 0.5073
# Epoch 1993 | loss: 0.2821 | Validation score: 0.5333 | Test score: 0.4927
# Epoch 1994 | loss: 0.2859 | Validation score: 0.5276 | Test score: 0.5117
# Epoch 1995 | loss: 0.2796 | Validation score: 0.5292 | Test score: 0.5125
# Epoch 1996 | loss: 0.2822 | Validation score: 0.5285 | Test score: 0.5065
# Epoch 1997 | loss: 0.2830 | Validation score: 0.5294 | Test score: 0.5125
# Epoch 1998 | loss: 0.2810 | Validation score: 0.5299 | Test score: 0.4980
# Epoch 1999 | loss: 0.2842 | Validation score: 0.5267 | Test score: 0.5093
# Epoch 2000 | loss: 0.2822 | Validation score: 0.5280 | Test score: 0.5073

# %%
import torch
import numpy as np
import torchvision.datasets as dataset
import torchvision.transforms as transforms
from torchvision import utils
import matplotlib.pyplot as plt

# %%
epoch_graph=np.arange(1,2001)

plt.plot(epoch_graph,myloss)
plt.title('training loss')
plt.xlabel('epochs')
plt.ylabel('Training loss')
plt.show()

plt.plot(epoch_graph,myvalaccuracy)
plt.title('val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()

plt.plot(epoch_graph,mytestaccuracy)
plt.title('test accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()
